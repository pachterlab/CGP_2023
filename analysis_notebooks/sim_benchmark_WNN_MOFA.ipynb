# %% [markdown]
# # **In this notebook we run the R methods WNN and MOFA+ for benchmarking clustering**

# %% [markdown]
# All data used for benchmarking can be downloaded from the command line (see commented code below)

# %%
# Loom files for simulation data
# Run code below in command line
# wget --content-disposition https://data.caltech.edu/records/mzs5b-72897/files/meK_sim_looms.tar.gz?download=1
# tar -xvf meK_sim_looms.tar.gz

# wget --content-disposition https://data.caltech.edu/records/2tsha-rcz19/files/meK_looms.tar.gz?download=1
# tar -xvf meK_looms.tar.gz

# %%
# if (!require("BiocManager", quietly = TRUE))
#     install.packages("BiocManager")

# BiocManager::install("scater")
# install.packages('Seurat')
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.18 (BiocManager 1.30.22), R 4.3.2 (2023-10-31)
#
# Installing package(s) 'BiocVersion', 'scater'
#
# also installing the dependencies ‘zlibbioc’, ‘bitops’, ‘XVector’, ‘sparseMatrixStats’, ‘RCurl’, ‘GenomeInfoDbData’, ‘abind’, ‘lambda.r’, ‘futile.options’, ‘sitmo’, ‘GenomicRanges’, ‘DelayedMatrixStats’, ‘Biobase’, ‘IRanges’, ‘GenomeInfoDb’, ‘S4Arrays’, ‘SparseArray’, ‘matrixStats’, ‘RcppHNSW’, ‘ScaledMatrix’, ‘irlba’, ‘rsvd’, ‘futile.logger’, ‘snow’, ‘BH’, ‘beeswarm’, ‘vipor’, ‘gridExtra’, ‘FNN’, ‘RcppAnnoy’, ‘RcppProgress’, ‘dqrng’, ‘Cairo’, ‘png’, ‘SingleCellExperiment’, ‘scuttle’, ‘BiocGenerics’, ‘S4Vectors’, ‘SummarizedExperiment’, ‘DelayedArray’, ‘MatrixGenerics’, ‘beachmat’, ‘BiocNeighbors’, ‘BiocSingular’, ‘BiocParallel’, ‘ggbeeswarm’, ‘viridis’, ‘Rtsne’, ‘RcppML’, ‘uwot’, ‘pheatmap’, ‘ggrepel’, ‘ggrastr’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Old packages: 'curl', 'data.table', 'MASS'

# %%
# if (!requireNamespace("remotes", quietly = TRUE)) {
#   install.packages("remotes")
# }
# remotes::install_github("mojaveazure/seurat-disk")

# %%
# if (!requireNamespace("BiocManager", quietly = TRUE))
#     install.packages("BiocManager")

# BiocManager::install("MOFA2")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.18 (BiocManager 1.30.22), R 4.3.2 (2023-10-31)
#
# Installing package(s) 'MOFA2'
#
# also installing the dependencies ‘filelock’, ‘Rhdf5lib’, ‘rhdf5filters’, ‘dir.expiry’, ‘basilisk.utils’, ‘rhdf5’, ‘HDF5Array’, ‘corrplot’, ‘basilisk’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Old packages: 'beachmat', 'BiocManager', 'boot', 'bslib', 'callr', 'codetools',
#   'crul', 'curl', 'data.table', 'DBI', 'dbplyr', 'deldir', 'digest', 'fs',
#   'future', 'future.apply', 'GenomeInfoDb', 'ggplot2', 'globals', 'gtable',
#   'hdf5r', 'htmltools', 'httpuv', 'igraph', 'knitr', 'lattice', 'lava',
#   'matrixStats', 'munsell', 'openssl', 'parallelly', 'processx', 'promises',
#   'quantmod', 'ragg', 'RcppArmadillo', 'RcppEigen', 'recipes', 'remotes',
#   'repr', 'reticulate', 'rmarkdown', 'rstudioapi', 'rvest', 'S4Arrays', 'sass',
#   'Seurat', 'shape', 'shiny', 'sp', 'SparseArray', 'spatstat.explore',
#   'spatstat.geom', 'spatstat.random', 'stringi', 'survival', 'systemfonts',
#   'tidyselect', 'tinytex', 'uwot', 'xfun', 'zlibbioc'

# %%
# install.packages('aricode')

# %%
library(scater)
library(Seurat)
library(SeuratDisk)
# library(SeuratData)
library(patchwork)
library(aricode)
library(tidyverse)
library(MOFA2)

# %%
num_runs <- 3

# %% [markdown]
# ## **Run on benchmark data**

# %%
looms <- c('./hvg_objs_0215/cl5_357hvgs.loom',
 './hvg_objs_0215/cl5_1193all.loom',
 './hvg_objs_0215/allen_b02h01a02_359hvgs.loom',
 './hvg_objs_0215/cl3_466hvgs.loom',
 './hvg_objs_0215/allen_b08_682hvgs.loom',
 './hvg_objs_0215/allen_b02h01a02_2770all.loom',
 './hvg_objs_0215/cl3_1137all.loom',
 './hvg_objs_0215/allen_b08_1948all.loom')

#'allen_b08', 'allen_b02h01', 'cl3', 'cl5', 'brca1', 'pbmc','e11e13'
shorts <- c('cl5','cl5','allen_b02h01a02','cl3','allen_b08','allen_b02h01a02',
           'cl3','allen_b08')

# %% [markdown]
# ### **MOFA2**

# %%
res <- 1
xy <- vector("list", num_runs*2*length(shorts)) # create an empty list into which values are to be filled
ind <- 0

for (o in 1:length(looms)){
    a08 <- Connect(filename = looms[o], mode = "r")
    
    
    # gene list
    n_genes <- a08[['row_attrs']][['gene_name']][['dims']]
    gns <- a08[['row_attrs']][['gene_name']][1:n_genes]
    
    # cell ID list
    n_cells <- a08[['col_attrs']][['barcode']][['dims']]
    cellids <- a08[['col_attrs']][['barcode']][1:n_cells]
    celllabs <- a08[['col_attrs']][['subclass_label']][1:n_cells]
    
    # get raw counts matrix
    raw.cnts <- t(a08[["layers/unspliced"]][,])
    colnames(raw.cnts) <- cellids
    # rownames(raw.cnts) <- gns
    
    
    metadata <- data.frame(
        cellID = cellids
        )
    rownames(metadata) <- cellids
    
    
    
    s_obj <- CreateSeuratObject(counts = raw.cnts,
                                project = "fromLoom",
                                assay = "URNA",
                                meta.data = metadata)
    
    sraw.cnts <- t(a08[["layers/spliced"]][,])
    colnames(sraw.cnts) <- cellids

    a08$close_all()

    num_features <- nrow(s_obj)
    print(looms[o])
    
    for (nr in 1:num_runs){
        # --- Running MOFA2 -----
        MOFAobject <- create_mofa(list(raw.cnts,sraw.cnts))
        data_opts <- get_default_data_options(MOFAobject)
        data_opts$scale_views <- TRUE
        model_opts <- get_default_model_options(MOFAobject)
        train_opts <- get_default_training_options(MOFAobject)
    
        MOFAobject <- prepare_mofa(
          object = MOFAobject,
          data_options = data_opts,
          model_options = model_opts,
          training_options = train_opts
        )
        outfile = file.path(getwd(),"model.hdf5")
        MOFAobject.trained <- run_mofa(MOFAobject, outfile)
        
        model <- load_model(outfile)
    
        factors <- get_factors(model)$group1
    
    
        pca_embeddings_mofa <- factors
        rownames(pca_embeddings_mofa) <- colnames(s_obj)
        colnames(pca_embeddings_mofa) <- colnames(factors)
        s_obj[["test"]] <- CreateDimReducObject(embeddings = as.matrix(pca_embeddings_mofa), key='Factor', assay = 'URNA')
        
        s_obj <- FindNeighbors(s_obj,reduction = 'test',graph.name = 'mofa',dims =1:dim(factors)[2])
    
        
        #Get leiden clusters for different res
        s_obj <- FindClusters(s_obj,graph.name='mofa',  algorithm = 4, resolution = res, verbose = FALSE, cluster.name='leiden')
        ind <- ind+1
        xy[[ind]] <- data.frame(Method = 'MOFA2-Leiden',
                            Clustering = I(list(s_obj[['leiden']]$leiden)),
                            Matrices = 'U,S',
                            Hyperparam = res,
                            HVGs = num_features ,
                            Data = shorts[o],
                            ARI = ARI(celllabs,s_obj[['leiden']]$leiden),
                            AMI = AMI(celllabs,s_obj[['leiden']]$leiden))

        print(ARI(celllabs,s_obj[['leiden']]$leiden))
    
    
    
        k <- length(unique(celllabs))
        d <- cluster_samples(model, k=k)

        ind <- ind+1
        xy[[ind]] <- data.frame(Method = 'MOFA2-K-Means',
                            Clustering = paste(d$cluster,collapse="|"),
                            Matrices = 'U,S',
                            Hyperparam = res,
                            HVGs = num_features ,
                            Data = shorts[o],
                            ARI = ARI(celllabs,d$cluster),
                            AMI = AMI(celllabs,d$cluster))
        print(ARI(celllabs,d$cluster))
    
        # --- Running MOFA2 -----
    }
    

    

}

xy <- do.call(rbind, xy)

xy %>% 
  rowwise() %>% 
  mutate_if(is.list, ~paste(unlist(.), collapse = '|')) %>% 
  write.csv('./fits/Seuratruns_0508/MOFA_bench_results.csv', row.names = FALSE)

head(xy)
#shorts[o]
# Out:
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# [1] "./hvg_objs_0215/cl5_357hvgs.loom"
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.5606682
# [1] 0.7344283
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.5606682
# [1] 0.6284335
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.5606682
# [1] 0.8961504
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# [1] "./hvg_objs_0215/cl5_1193all.loom"
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.5452449
# [1] 0.6902323
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.5452449
# [1] 0.7207902
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.5452449
# [1] 0.8075214
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# [1] "./hvg_objs_0215/allen_b02h01a02_359hvgs.loom"
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 4.1 GiB”
# [1] 0.4263297
# [1] 0.3525554
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 4.1 GiB”
# [1] 0.4263297
# [1] 0.2213768
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 4.1 GiB”
# [1] 0.4263297
# [1] 0.2582337
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# [1] "./hvg_objs_0215/cl3_466hvgs.loom"
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.4419543
# [1] 0.6561983
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.4419543
# [1] 0.6068863
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.4419543
# [1] 0.6356439
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# [1] "./hvg_objs_0215/allen_b08_682hvgs.loom"
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.2973622
# [1] 0.231527
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.2973622
# [1] 0.2141116
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.2973622
# [1] 0.2506011
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# [1] "./hvg_objs_0215/allen_b02h01a02_2770all.loom"
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 4.1 GiB”
# [1] 0.4480626
# [1] 0.2006984
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 4.1 GiB”
# [1] 0.4480626
# [1] 0.2140604
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 4.1 GiB”
# [1] 0.4480626
# [1] 0.263312
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# [1] "./hvg_objs_0215/cl3_1137all.loom"
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.5136633
# [1] 0.9932934
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.5136633
# [1] 0.4477983
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.5136633
# [1] 0.9932934
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# [1] "./hvg_objs_0215/allen_b08_1948all.loom"
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.3108353
# [1] 0.2529561
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.3108353
# [1] 0.2048092
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.3108353
# [1] 0.217718
#   Method        Clustering   Matrices Hyperparam HVGs Data ARI       AMI
# 1 MOFA2-Leiden  1, 1, 10.... U,S      1          357  cl5  0.5606682 0.6296090
# 2 MOFA2-K-Means 4|4|3|4|.... U,S      1          357  cl5  0.7344283 0.7512999
# 3 MOFA2-Leiden  1, 1, 10.... U,S      1          357  cl5  0.5606682 0.6296090
# 4 MOFA2-K-Means 4|4|5|4|.... U,S      1          357  cl5  0.6284335 0.7499459
# 5 MOFA2-Leiden  1, 1, 10.... U,S      1          357  cl5  0.5606682 0.6296090
# 6 MOFA2-K-Means 1|1|2|1|.... U,S      1          357  cl5  0.8961504 0.8612450

# %%
xy
# Out:
#    Method        Clustering   Matrices Hyperparam HVGs Data
# 1  MOFA2-Leiden  1, 1, 10.... U,S      1           357 cl5
# 2  MOFA2-K-Means 4|4|3|4|.... U,S      1           357 cl5
# 3  MOFA2-Leiden  1, 1, 10.... U,S      1           357 cl5
# 4  MOFA2-K-Means 4|4|5|4|.... U,S      1           357 cl5
# 5  MOFA2-Leiden  1, 1, 10.... U,S      1           357 cl5
# 6  MOFA2-K-Means 1|1|2|1|.... U,S      1           357 cl5
# 7  MOFA2-Leiden  1, 1, 7,.... U,S      1          1193 cl5
# 8  MOFA2-K-Means 2|2|1|2|.... U,S      1          1193 cl5
# 9  MOFA2-Leiden  1, 1, 7,.... U,S      1          1193 cl5
# 10 MOFA2-K-Means 4|4|3|4|.... U,S      1          1193 cl5
# 11 MOFA2-Leiden  1, 1, 7,.... U,S      1          1193 cl5
# 12 MOFA2-K-Means 2|2|5|2|.... U,S      1          1193 cl5
# 13 MOFA2-Leiden  15, 2, 2.... U,S      1           359 allen_b02h01a02
# 14 MOFA2-K-Means 1|4|4|7|.... U,S      1           359 allen_b02h01a02
# 15 MOFA2-Leiden  15, 2, 2.... U,S      1           359 allen_b02h01a02
# 16 MOFA2-K-Means 2|4|5|3|.... U,S      1           359 allen_b02h01a02
# 17 MOFA2-Leiden  15, 2, 2.... U,S      1           359 allen_b02h01a02
# 18 MOFA2-K-Means 1|10|1|2.... U,S      1           359 allen_b02h01a02
# 19 MOFA2-Leiden  8, 4, 4,.... U,S      1           466 cl3
# 20 MOFA2-K-Means 3|3|3|3|.... U,S      1           466 cl3
# 21 MOFA2-Leiden  8, 4, 4,.... U,S      1           466 cl3
# 22 MOFA2-K-Means 1|1|1|1|.... U,S      1           466 cl3
# 23 MOFA2-Leiden  8, 4, 4,.... U,S      1           466 cl3
# 24 MOFA2-K-Means 1|1|1|1|.... U,S      1           466 cl3
# 25 MOFA2-Leiden  3, 7, 11.... U,S      1           682 allen_b08
# 26 MOFA2-K-Means 5|1|6|5|.... U,S      1           682 allen_b08
# 27 MOFA2-Leiden  3, 7, 11.... U,S      1           682 allen_b08
# 28 MOFA2-K-Means 8|8|1|3|.... U,S      1           682 allen_b08
# 29 MOFA2-Leiden  3, 7, 11.... U,S      1           682 allen_b08
# 30 MOFA2-K-Means 10|10|6|.... U,S      1           682 allen_b08
# 31 MOFA2-Leiden  14, 2, 2.... U,S      1          2770 allen_b02h01a02
# 32 MOFA2-K-Means 9|1|4|10.... U,S      1          2770 allen_b02h01a02
# 33 MOFA2-Leiden  14, 2, 2.... U,S      1          2770 allen_b02h01a02
# 34 MOFA2-K-Means 7|3|9|8|.... U,S      1          2770 allen_b02h01a02
# 35 MOFA2-Leiden  14, 2, 2.... U,S      1          2770 allen_b02h01a02
# 36 MOFA2-K-Means 10|1|1|3.... U,S      1          2770 allen_b02h01a02
# 37 MOFA2-Leiden  2, 5, 5,.... U,S      1          1137 cl3
# 38 MOFA2-K-Means 1|1|1|1|.... U,S      1          1137 cl3
# 39 MOFA2-Leiden  2, 5, 5,.... U,S      1          1137 cl3
# 40 MOFA2-K-Means 1|2|1|1|.... U,S      1          1137 cl3
# 41 MOFA2-Leiden  2, 5, 5,.... U,S      1          1137 cl3
# 42 MOFA2-K-Means 2|2|2|2|.... U,S      1          1137 cl3
# 43 MOFA2-Leiden  3, 7, 13.... U,S      1          1948 allen_b08
# 44 MOFA2-K-Means 8|8|4|2|.... U,S      1          1948 allen_b08
# 45 MOFA2-Leiden  3, 7, 13.... U,S      1          1948 allen_b08
# 46 MOFA2-K-Means 4|2|6|4|.... U,S      1          1948 allen_b08
# 47 MOFA2-Leiden  3, 7, 13.... U,S      1          1948 allen_b08
# 48 MOFA2-K-Means 7|7|8|5|.... U,S      1          1948 allen_b08
#    ARI       AMI
# 1  0.5606682 0.6296090
# 2  0.7344283 0.7512999
# 3  0.5606682 0.6296090
# 4  0.6284335 0.7499459
# 5  0.5606682 0.6296090
# 6  0.8961504 0.8612450
# 7  0.5452449 0.6301100
# 8  0.6902323 0.7032125
# 9  0.5452449 0.6301100
# 10 0.7207902 0.7264055
# 11 0.5452449 0.6301100
# 12 0.8075214 0.8107276
# 13 0.4263297 0.6138486
# 14 0.3525554 0.6069725
# 15 0.4263297 0.6138486
# 16 0.2213768 0.5415858
# 17 0.4263297 0.6138486
# 18 0.2582337 0.5469327
# 19 0.4419543 0.4903716
# 20 0.6561983 0.7100744
# 21 0.4419543 0.4903716
# 22 0.6068863 0.6753173
# 23 0.4419543 0.4903716
# 24 0.6356439 0.6960744
# 25 0.2973622 0.5566360
# 26 0.2315270 0.5144203
# 27 0.2973622 0.5566360
# 28 0.2141116 0.4801772
# 29 0.2973622 0.5566360
# 30 0.2506011 0.5116350
# 31 0.4480626 0.6304774
# 32 0.2006984 0.5235914
# 33 0.4480626 0.6304774
# 34 0.2140604 0.5449329
# 35 0.4480626 0.6304774
# 36 0.2633120 0.5518207
# 37 0.5136633 0.5443877
# 38 0.9932934 0.9863418
# 39 0.5136633 0.5443877
# 40 0.4477983 0.5713157
# 41 0.5136633 0.5443877
# 42 0.9932934 0.9863418
# 43 0.3108353 0.5653300
# 44 0.2529561 0.5225924
# 45 0.3108353 0.5653300
# 46 0.2048092 0.4739986
# 47 0.3108353 0.5653300
# 48 0.2177180 0.4993231

# %% [markdown]
# ### **WNN**

# %%
res <- c(0.75,1,1.5,2)
xy <- vector("list", num_runs*length(res)*length(shorts)) # create an empty list into which values are to be filled

ind <- 0 
for (o in 1:length(looms)){
    a08 <- Connect(filename = looms[o], mode = "r")
    
    
    # gene list
    n_genes <- a08[['row_attrs']][['gene_name']][['dims']]
    gns <- a08[['row_attrs']][['gene_name']][1:n_genes]
    
    # cell ID list
    n_cells <- a08[['col_attrs']][['barcode']][['dims']]
    cellids <- a08[['col_attrs']][['barcode']][1:n_cells]
    celllabs <- a08[['col_attrs']][['subclass_label']][1:n_cells]
    
    # get raw counts matrix
    raw.cnts <- t(a08[["layers/unspliced"]][,])
    colnames(raw.cnts) <- cellids
    # rownames(raw.cnts) <- gns
    
    
    metadata <- data.frame(
        cellID = cellids
        )
    rownames(metadata) <- cellids
    
    
    
    s_obj <- CreateSeuratObject(counts = raw.cnts,
                                project = "fromLoom",
                                assay = "URNA",
                                meta.data = metadata)
    
    sraw.cnts <- t(a08[["layers/spliced"]][,])
    colnames(sraw.cnts) <- cellids
    
    s_assay <- CreateAssay5Object(counts = sraw.cnts)
    
    s_obj[["SRNA"]] <- s_assay
    
    a08$close_all()
    
    DefaultAssay(s_obj) <- 'URNA'
    s_obj <- NormalizeData(s_obj) 
    # s_obj <- FindVariableFeatures(s_obj) 
    s_obj <- ScaleData(s_obj) 
    s_obj <- RunPCA(s_obj,reduction.name = 'upca', features = Features(s_obj))
    
    DefaultAssay(s_obj) <- 'SRNA'
    s_obj <- NormalizeData(s_obj) 
    # s_obj <- FindVariableFeatures(s_obj)
    s_obj <- ScaleData(s_obj)
    s_obj <- RunPCA(s_obj,reduction.name = 'spca',features = Features(s_obj))
    
    for (nr in 1:num_runs){
        s_obj <- FindMultiModalNeighbors(
          s_obj, reduction.list = list("upca", "spca"), 
          dims.list = list(1:30, 1:30), modality.weight.name = "RNA.weight"
        )
        print(nr)
        #Run Leiden here + save results
        num_features <- nrow(s_obj)
        
        
        for (i in 1:length(res)) {
          ind <- ind + 1
          #Get leiden clusters for different res
          s_obj <- FindClusters(s_obj, graph.name = "wsnn", algorithm = 4, resolution = res[i], verbose = FALSE, cluster.name='leiden')
          #ind <- (o-1)*length(res) + i 
          xy[[ind]] <- data.frame(Method = 'WNN-Leiden',
                                Clustering = I(list(s_obj[['leiden']]$leiden)),
                                Matrices = 'U,S',
                                Hyperparam = res[i],
                                HVGs = num_features ,
                                Data = shorts[o],
                                ARI = ARI(celllabs,s_obj[['leiden']]$leiden),
                                AMI = AMI(celllabs,s_obj[['leiden']]$leiden))
        }
    }

}

xy <- do.call(rbind, xy)

xy %>% 
  rowwise() %>% 
  mutate_if(is.list, ~paste(unlist(.), collapse = '|')) %>% 
  write.csv('./fits/Seuratruns_0508/WNN_bench_results.csv', row.names = FALSE)
  #write.csv('./fits/Seuratruns_0215/WNN_bench_results.csv', row.names = FALSE)


head(xy)
#shorts[o]
# Out:
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# Normalizing layer: counts
#
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  Feature120, Feature305, Feature74, Feature170, Feature270, Feature54, Feature57, Feature100, Feature236, Feature86
# 	   Feature8, Feature55, Feature317, Feature82, Feature203, Feature240, Feature96, Feature140, Feature278, Feature122
# 	   Feature159, Feature216, Feature324, Feature87, Feature251, Feature53, Feature243, Feature237, Feature220, Feature310
# Negative:  Feature334, Feature81, Feature181, Feature303, Feature177, Feature302, Feature212, Feature84, Feature133, Feature304
# 	   Feature110, Feature35, Feature91, Feature47, Feature336, Feature138, Feature178, Feature106, Feature254, Feature332
# 	   Feature257, Feature46, Feature245, Feature233, Feature226, Feature311, Feature51, Feature356, Feature264, Feature287
# PC_ 2
# Positive:  Feature165, Feature332, Feature45, Feature46, Feature172, Feature334, Feature304, Feature120, Feature305, Feature54
# 	   Feature171, Feature57, Feature122, Feature47, Feature245, Feature81, Feature303, Feature110, Feature302, Feature177
# 	   Feature86, Feature278, Feature212, Feature74, Feature55, Feature351, Feature345, Feature106, Feature203, Feature240
# Negative:  Feature69, Feature158, Feature36, Feature18, Feature288, Feature68, Feature213, Feature214, Feature296, Feature268
# 	   Feature85, Feature318, Feature12, Feature182, Feature65, Feature266, Feature88, Feature26, Feature261, Feature174
# 	   Feature16, Feature128, Feature335, Feature346, Feature52, Feature143, Feature323, Feature38, Feature139, Feature234
# PC_ 3
# Positive:  Feature18, Feature65, Feature68, Feature69, Feature229, Feature266, Feature288, Feature318, Feature91, Feature85
# 	   Feature88, Feature74, Feature214, Feature211, Feature52, Feature16, Feature26, Feature137, Feature158, Feature59
# 	   Feature92, Feature36, Feature159, Feature174, Feature234, Feature155, Feature96, Feature101, Feature346, Feature89
# Negative:  Feature323, Feature326, Feature321, Feature294, Feature335, Feature325, Feature70, Feature291, Feature83, Feature73
# 	   Feature79, Feature117, Feature71, Feature82, Feature230, Feature337, Feature224, Feature236, Feature30, Feature119
# 	   Feature138, Feature239, Feature312, Feature2, Feature330, Feature241, Feature163, Feature112, Feature167, Feature317
# PC_ 4
# Positive:  Feature217, Feature188, Feature153, Feature353, Feature5, Feature147, Feature94, Feature149, Feature145, Feature340
# 	   Feature289, Feature66, Feature247, Feature152, Feature299, Feature314, Feature199, Feature99, Feature158, Feature105
# 	   Feature175, Feature261, Feature134, Feature295, Feature327, Feature228, Feature193, Feature73, Feature8, Feature271
# Negative:  Feature132, Feature89, Feature22, Feature326, Feature79, Feature183, Feature291, Feature117, Feature317, Feature256
# 	   Feature7, Feature244, Feature319, Feature227, Feature70, Feature35, Feature184, Feature325, Feature312, Feature91
# 	   Feature83, Feature135, Feature29, Feature130, Feature10, Feature230, Feature18, Feature21, Feature72, Feature128
# PC_ 5
# Positive:  Feature22, Feature132, Feature227, Feature128, Feature183, Feature256, Feature319, Feature7, Feature89, Feature21
# 	   Feature10, Feature130, Feature135, Feature108, Feature37, Feature184, Feature244, Feature353, Feature217, Feature19
# 	   Feature97, Feature5, Feature153, Feature94, Feature149, Feature158, Feature152, Feature188, Feature49, Feature299
# Negative:  Feature79, Feature83, Feature291, Feature326, Feature154, Feature117, Feature70, Feature317, Feature30, Feature112
# 	   Feature230, Feature312, Feature68, Feature125, Feature325, Feature270, Feature71, Feature77, Feature344, Feature116
# 	   Feature318, Feature213, Feature170, Feature306, Feature222, Feature4, Feature288, Feature36, Feature349, Feature11
#
# Normalizing layer: counts
#
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  Fe
# 	   Feature847, Feature525, Feature922, Feature532, Feature543, Feature493, Feature213, Feature709, Feature692, Feature971
# PC_ 5
# Positive:  Feature434, Feature69, Feature374, Feature880, Feature127, Feature26, Feature422, Feature16, Feature597, Feature780
# 	   Feature356, Feature698, Feature646, Feature620, Feature1072, Feature35, Feature647, Feature985, Feature89, Feature321
# 	   Feature444, Feature426, Feature562, Feature73, Feature1178, Feature91, Feature669, Feature838, Feature298, Feature404
# Negative:  Feature993, Feature1117, Feature412, Feature270, Feature120, Feature978, Feature643, Feature1069, Feature10, Feature1100
# 	   Feature925, Feature290, Feature1098, Feature529, Feature758, Feature90, Feature232, Feature860, Feature366, Feature706
# 	   Feature84, Feature752, Feature760, Feature1078, Feature1094, Feature230, Feature263, Feature914, Feature107, Feature303
#
# Warning message:
# “Key ‘PC_’ taken, using ‘spca_’ instead”
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
# [1] 1
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
# [1] 2
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
# [1] 3
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# Normalizing layer: counts
#
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  Feature275, Feature49, Feature338, Feature83, Feature179, Feature165, Feature56, Feature106, Feature28, Feature180
# 	   Feature308, Feature276, Feature16, Feature234, Feature230, Feature109, Feature107, Feature161, Feature128, Feature116
# 	   Feature99, Feature42, Feature61, Feature186, Feature175, Feature154, Feature204, Feature330, Feature171, Feature242
# Negative:  Feature279, Feature29, Feature148, Feature174, Feature296, Feature266, Feature189, Feature288, Feature125, Feature299
# 	   Feature246, Feature67, Feature144, Feature40, Feature340, Feature322, Feature192, Feature64, Feature72, Feature331
# 	   Feature4, Feature8, Feature224, Feature219, Feature309, Feature318, Feature191, Feature115, Feature146, Feature71
# PC_ 2
# Positive:  Feature276, Feature227, Feature113, Feature164, Feature47, Feature116, Feature104, Feature65, Feature128, Feature242
# 	   Feature10, Feature55, Feature234, Feature308, Feature272, Feature357, Feature231, Feature295, Feature56, Feature344
# 	   Feature334, Feature16, Feature142, Feature230, Feature250, Feature205, Feature349, Feature83, Feature338, Feature45
# Negative:  Feature283, Feature121, Feature63, Feature79, Feature154, Feature96, Feature271, Feature353, Feature38, Feature354
# 	   Feature225, Feature28, Feature244, Feature313, Feature165, Feature120, Feature24, Feature109, Feature9, Feature229
# 	   Feature253, Feature222, Feature86, Feature330, Feature217, Feature257, Feature264, Feature51, Feature216, Feature303
# PC_ 3
# Positive:  Feature333, Feature36, Feature129, Feature179, Feature300, Feature16, Feature343, Feature91, Feature353, Feature264
# 	   Feature104, Feature225, Feature79, Feature230, Feature341, Feature170, Feature234, Feature163, Feature122, Feature303
# 	   Feature138, Feature139, Feature253, Feature94, Feature159, Feature204, Feature270, Feature120, Feature121, Feature345
# Negative:  Feature162, Feature220, Feature5, Feature135, Feature255, Feature14, Feature215, Feature199, Feature178, Feature213
# 	   Feature150, Feature61, Feature141, Feature313, Feature99, Feature231, Feature275, Feature194, Feature136, Feature23
# 	   Feature48, Feature342, Feature248, Feature187, Feature111, Feature211, Feature285, Feature41, Feature358, Feature12
# PC_ 4
# Positive:  Feature112, Feature140, Feature5, Feature58, Feature204, Feature324, Feature132, Feature23, Feature358, Feature111
# 	   Feature268, Feature254, Feature187, Feature255, Feature56, Feature251, Feature256, Feature3, Feature186, Feature158
# 	   Feature216, Feature101, Feature92, Feature119, Feature284, Feature203, Feature165, Feature319, Feature270, Feature281
# Negative:  Feature157, Feature68, Feature271, Feature46, Feature42, Feature238, Feature51, Feature196, Feature320, Feature245
# 	   Feature13, Feature217, Feature141, Feature297, Feature276, Feature6, Feature153, Feature225, Feature28, Feature18
# 	   Feature62, Feature228, Feature59, Feature61, Feature329, Feature10, Feature242, Feature32, Feature102, Feature179
# PC_ 5
# Positive:  Feature61, Feature242, Feature96, Feature164, Feature49, Feature190, Feature66, Feature207, Feature153, Feature285
# 	   Feature79, Feature256, Feature10, Feature141, Feature106, Feature37, Feature218, Feature179, Feature283, Feature202
# 	   Feature163, Feature292, Feature276, Feature22, Feature14, Feature307, Feature136, Feature272, Feature344, Feature319
# Negative:  Feature211, Feature97, Feature68, Feature215, Feature157, Feature212, Feature289, Feature140, Feature6, Feature42
# 	   Feature104, Feature298, Feature30, Feature311, Feature51, Feature112, Feature165, Feature46, Feature324, Feature245
# 	   Feature269, Feature329, Feature238, Feature59, Feature332, Feature195, Feature254, Feature221, Feature196, Feature119
#
# Normalizing layer: counts
#
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  Feature162, Feature179, Feature283, Feature13, Feature56, Feature106, Feature83, Feature308, Feature168, Feature164
# 	   Feature99, Feature276, Feature49, Feature329, Feature344, Feature275, Feature234, Feature17, Feature25, Feature282
# 	   Feature165, Feature161, Feature28, Feature250, Feature116, Feature16, Feature109, Feature6, Feature216, Feature126
# Negative:  Feature246, Feature331, Feature266, Feature288, Feature299, Feature279, Feature318, Feature98, Feature189, Feature296
# 	   Feature174, Feature72, Feature148, Feature183, Feature219, Feature309, Feature224, Feature67, Feature9, Feature41
# 	   Feature19, Feature80, Feature40, Feature64, Feature29, Feature257, Feature4, Feature125, Feature304, Feature146
# PC_ 2
# Positive:  Feature283, Feature271, Feature7, Feature216, Feature96, Feature225, Feature162, Feature109, Feature121, Feature79
# 	   Feature354, Feature197, Feature28, Feature48, Feature154, Feature353, Feature223, Feature253, Feature63, Feature217
# 	   Feature61, Feature99, Feature51, Feature165, Feature24, Feature122, Feature303, Feature120, Feature73, Feature9
# Negative:  Feature164, Feature276, Feature168, Feature65, Feature104, Feature344, Feature55, Feature234, Feature308, Feature56
# 	   Feature116, Feature113, Feature10, Feature334, Feature357, Feature47, Feature231, Feature227, Feature349, Feature128
# 	   Feature6, Feature190, Feature25, Feature126, Feature16, Feature250, Feature83, Feature45, Feature156, Feature205
# PC_ 3
# Positive:  Feature247, Feature122, Feature179, Feature79, Feature312, Feature138, Feature36, Feature163, Feature288, Feature237
# 	   Feature39, Feature127, Feature333, Feature225, Feature292, Feature271, Feature129, Feature131, Feature234, Feature265
# 	   Feature28, Feature277, Feature121, Feature345, Feature359, Feature109, Feature174, Feature300, Feature218, Feature1
# Negative:  Feature162, Feature194, Feature216, Feature13, Feature5, Feature99, Feature220, Feature61, Feature246, Feature231
# 	   Feature135, Feature213, Feature212, Feature331, Feature19, Feature136, Feature211, Feature98, Feature255, Feature199
# 	   Feature48, Feature275, Feature187, Feature228, Feature41, Feature313, Feature143, Feature241, Feature248, Feature215
# PC_ 4
# Positive:  Feature246, Feature98, Feature179, Feature19, Feature297, Feature223, Feature290, Feature251, Feature331, Feature271
# 	   Feature219, Feature311, Feature261, Feature109, Feature139, Feature138, Feature4, Feature163, Feature234, Feature28
# 	   Feature40, Feature106, Feature214, Feature29, Feature283, Feature34, Feature276, Feature300, Feature194, Feature345
# Negative:  Feature312, Feature247, Feature39, Feature288, Feature291, Feature67, Feature94, Feature277, Feature174, Feature347
# 	   Feature342, Feature328, Feature286, Feature262, Feature240, Feature162, Feature265, Feature85, Feature241, Feature125
# 	   Feature190, Feature287, Feature136, Feature144, Feature5, Feature263, Feature220, Feature296, Feature221, Feature60
# PC_ 5
# Positive:  Feature13, Feature247, Feature288, Feature296, Feature246, Feature279, Feature228, Feature189, Feature162, Feature219
# 	   Feature12, Feature194, Feature25, Feature174, Feature18, Feature312, Feature297, Feature311, Feature29, Feature98
# 	   Feature168, Feature72, Feature60, Feature48, Feature248, Feature183, Feature39, Feature271, Feature221, Feature144
# Negative:  Feature190, Feature347, Feature7, Feature319, Feature231, Feature96, Feature158, Feature66, Feature3, Feature240
# 	   Feature243, Feature283, Feature256, Feature342, Feature301, Feature45, Feature65, Feature186, Feature201, Feature262
# 	   Feature36, Feature95, Feature324, Feature295, Feature285, Feature218, Feature187, Feature307, Feature179, Feature327
#
# Warning message:
# “Key ‘PC_’ taken, using ‘spca_’ instead”
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
# [1] 1
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 4.1 GiB”
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 4.1 GiB”
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 4.1 GiB”
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 4.1 GiB”
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
# [1] 2
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 4.1 GiB”
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 4.1 GiB”
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 4.1 GiB”
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 4.1 GiB”
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
# [1] 3
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 4.1 GiB”
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 4.1 GiB”
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 4.1 GiB”
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 4.1 GiB”
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# Normalizing layer: counts
#
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  Feature107, Feature86, Feature353, Feature69, Feature287, Feature60, Feature239, Feature402, Feature337, Feature227
# 	   Feature80, Feature155, Feature286, Feature64, Feature362, Feature336, Feature458, Feature236, Feature54, Feature348
# 	   Feature127, Feature410, Feature79, Feature323, Feature331, Feature193, Feature432, Feature314, Feature274, Feature222
# Negative:  Feature344, Feature431, Feature53, Feature404, Feature427, Feature14, Feature248, Feature389, Feature283, Feature388
# 	   Feature426, Feature220, Feature302, Feature99, Feature154, Feature129, Feature206, Feature115, Feature104, Feature186
# 	   Feature211, Feature112, Feature422, Feature385, Feature116, Feature400, Feature391, Feature189, Feature67, Feature382
# PC_ 2
# Positive:  Feature426, Feature389, Feature105, Feature114, Feature186, Feature115, Feature104, Feature24, Feature306, Feature385
# 	   Feature116, Feature450, Feature397, Feature28, Feature154, Feature19, Feature15, Feature349, Feature53, Feature300
# 	   Feature34, Feature404, Feature422, Feature12, Feature112, Feature67, Feature18, Feature423, Feature438, Feature329
# Negative:  Feature129, Feature302, Feature264, Feature220, Feature9, Feature211, Feature465, Feature391, Feature382, Feature189
# 	   Feature206, Feature199, Feature413, Feature218, Feature212, Feature204, Feature330, Feature136, Feature162, Feature192
# 	   Feature134, Feature126, Feature46, Feature343, Feature424, Feature276, Feature352, Feature143, Feature137, Feature11
# PC_ 3
# Positive:  Feature251, Feature420, Feature260, Feature99, Feature23, Feature273, Feature335, Feature159, Feature252, Feature448
# 	   Feature79, Feature400, Feature210, Feature135, Feature148, Feature187, Feature28, Feature193, Feature91, Feature53
# 	   Feature381, Feature280, Feature370, Feature295, Feature306, Feature289, Feature389, Feature444, Feature318, Feature61
# Negative:  Feature25, Feature313, Feature178, Feature10, Feature346, Feature421, Feature109, Feature36, Feature180, Feature255
# 	   Feature175, Feature156, Feature312, Feature173, Feature265, Feature123, Feature242, Feature347, Feature32, Feature309
# 	   Feature169, Feature366, Feature75, Feature373, Feature144, Feature218, Feature56, Feature12, Feature202, Feature285
# PC_ 4
# Positive:  Feature333, Feature154, Feature423, Feature134, Feature207, Feature166, Feature428, Feature85, Feature5, Feature11
# 	   Feature96, Feature165, Feature244, Feature388, Feature340, Feature465, Feature398, Feature294, Feature293, Feature150
# 	   Feature131, Feature170, Feature9, Feature136, Feature211, Feature126, Feature116, Feature189, Feature153, Feature304
# Negative:  Feature277, Feature427, Feature445, Feature61, Feature288, Feature97, Feature28, Feature354, Feature53, Feature88
# 	   Feature350, Feature381, Feature311, Feature430, Feature161, Feature434, Feature343, Feature338, Feature243, Feature36
# 	   Feature46, Feature344, Feature143, Feature52, Feature415, Feature279, Feature283, Feature234, Feature435, Feature312
# PC_ 5
# Positive:  Feature56, Feature75, Feature453, Feature400, Feature288, Feature311, Feature395, Feature464, Feature238, Feature401
# 	   Feature11, Feature243, Feature340, Feature319, Feature333, Feature1, Feature134, Feature289, Feature449, Feature396
# 	   Feature332, Feature348, Feature146, Feature447, Feature387, Feature3, Feature208, Feature144, Feature349, Feature163
# Negative:  Feature131, Feature294, Feature219, Feature85, Feature427, Feature466, Feature73, Feature153, Feature205, Feature213
# 	   Feature277, Feature96, Feature444, Feature304, Feature445, Feature71, Feature87, Feature161, Feature250, Feature437
# 	   Feature438, Feature265, Feature347, Feature374, Feature22, Feature317, Feature70, Feature322, Feature194, Feature91
#
# Normalizing layer: counts
#
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  Feature410, Feature378, Feature280, Feature458, Feature274, Feature79, Feature70, Feature124, Feature402, Feature239
# 	   Feature60, Feature151, Feature82, Feature71, Feature155, Feature107, Feature113, Feature336, Feature193, Feature69
# 	   Feature65, Feature351, Feature80, Feature362, Feature225, Feature367, Feature407, Feature305, Feature369, Feature227
# Negative:  Feature431, Feature14, Feature174, Feature291, Feature360, Feature427, Feature104, Feature344, Feature59, Feature248
# 	   Feature404, Feature42, Feature206, Feature197, Feature278, Feature115, Feature34, Feature385, Feature426, Feature137
# 	   Feature253, Feature207, Feature53, Feature169, Feature173, Feature99, Feature33, Feature216, Feature411, Feature19
# PC_ 2
# Positive:  Feature258, Feature137, Feature382, Feature264, Feature158, Feature143, Feature391, Feature126, Feature335, Feature9
# 	   Feature129, Feature211, Feature206, Feature161, Feature204, Feature197, Feature218, Feature325, Feature302, Feature199
# 	   Feature216, Feature202, Feature212, Feature201, Feature276, Feature191, Feature262, Feature273, Feature406, Feature110
# Negative:  Feature105, Feature426, Feature24, Feature33, Feature389, Feature403, Feature34, Feature186, Feature300, Feature114
# 	   Feature318, Feature115, Feature120, Feature428, Feature19, Feature116, Feature15, Feature74, Feature450, Feature154
# 	   Feature41, Feature275, Feature385, Feature53, Feature321, Feature329, Feature104, Feature35, Feature18, Feature308
# PC_ 3
# Positive:  Feature251, Feature99, Feature252, Feature390, Feature29, Feature376, Feature387, Feature15, Feature334, Feature144
# 	   Feature279, Feature363, Feature400, Feature91, Feature374, Feature59, Feature162, Feature275, Feature199, Feature433
# 	   Feature246, Feature13, Feature49, Feature330, Feature104, Feature17, Feature256, Feature132, Feature254, Feature28
# Negative:  Feature346, Feature178, Feature10, Feature313, Feature255, Feature32, Feature180, Feature421, Feature173, Feature36
# 	   Feature242, Feature265, Feature25, Feature169, Feature175, Feature109, Feature156, Feature123, Feature312, Feature347
# 	   Feature373, Feature75, Feature423, Feature333, Feature76, Feature201, Feature218, Feature136, Feature464, Feature161
# PC_ 4
# Positive:  Feature277, Feature279, Feature52, Feature68, Feature445, Feature175, Feature338, Feature290, Feature88, Feature178
# 	   Feature230, Feature32, Feature449, Feature223, Feature335, Feature156, Feature421, Feature354, Feature61, Feature180
# 	   Feature457, Feature10, Feature343, Feature396, Feature370, Feature243, Feature242, Feature307, Feature25, Feature235
# Negative:  Feature428, Feature22, Feature150, Feature207, Feature154, Feature423, Feature145, Feature58, Feature465, Feature333
# 	   Feature166, Feature329, Feature293, Feature11, Feature5, Feature384, Feature165, Feature205, Feature131, Feature87
# 	   Feature213, Feature153, Feature35, Feature134, Feature211, Feature20, Feature85, Feature325, Feature170, Feature417
# PC_ 5
# Positive:  Feature75, Feature92, Feature449, Feature307, Feature207, Feature465, Feature293, Feature11, Feature459, Feature333
# 	   Feature311, Feature166, Feature132, Feature243, Feature360, Feature208, Feature384, Feature134, Feature288, Feature241
# 	   Feature226, Feature387, Feature332, Feature348, Feature128, Feature157, Feature56, Feature83, Feature221, Feature163
# Negative:  Feature22, Feature445, Feature444, Feature205, Feature131, Feature87, Feature277, Feature437, Feature153, Feature213
# 	   Feature58, Feature85, Feature294, Feature219, Feature290, Feature466, Feature35, Feature2, Feature55, Feature99
# 	   Feature91, Feature139, Feature96, Feature418, Feature343, Feature161, Feature244, Feature304, Feature46, Feature230
#
# Warning message:
# “Key ‘PC_’ taken, using ‘spca_’ instead”
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
# [1] 1
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
# [1] 2
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
# [1] 3
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# Normalizing layer: counts
#
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  Feature136, Feature425, Feature504, Feature209, Feature198, Feature623, Feature519, Feature441, Feature24, Feature584
# 	   Feature620, Feature94, Feature117, Feature45, Feature215, Feature434, Feature299, Feature337, Feature565, Feature595
# 	   Feature156, Feature38, Feature529, Feature427, Feature61, Feature19, Feature497, Feature612, Feature677, Feature257
# Negative:  Feature77, Feature531, Feature89, Feature541, Feature297, Feature577, Feature243, Feature471, Feature399, Feature192
# 	   Feature159, Feature286, Feature527, Feature133, Feature494, Feature18, Feature364, Feature375, Feature95, Feature671
# 	   Feature411, Feature414, Feature407, Feature87, Feature173, Feature619, Feature473, Feature134, Feature350, Feature515
# PC_ 2
# Positive:  Feature318, Feature545, Feature355, Feature416, Feature514, Feature147, Feature66, Feature124, Feature80, Feature567
# 	   Feature48, Feature366, Feature487, Feature604, Feature681, Feature212, Feature103, Feature2, Feature602, Feature554
# 	   Feature368, Feature266, Feature526, Feature229, Feature480, Feature122, Feature663, Feature611, Feature146, Feature419
# Positive:  Feature494, Feature159, Feature77, Feature473, Feature619, Feature393, Feature89, Feature350, Feature544, Feature603
# 	   Feature414, Feature531, Feature127, Feature87, Feature602, Feature420, Feature307, Feature399, Feature671, Feature503
# 	   Feature444, Feature138, Feature541, Feature346, Feature567, Feature180, Feature514, Feature402, Feature675, Feature545
# Negative:  Feature504, Feature425, Feature432, Feature584, Feature117, Feature519, Feature136, Feature529, Feature209, Feature299
# 	   Feature102, Feature441, Feature434, Feature213, Feature582, Feature236, Feature45, Feature203, Feature595, Feature38
# 	   Feature215, Feature170, Feature561, Feature496, Feature517, Feature100, Feature163, Feature558, Feature198, Feature581
# PC_ 3
# Positive:  Feature469, Feature132, Feature32, Feature202, Feature333, Feature354, Feature76, Feature623, Feature468, Feature397
# 	   Feature51, Feature222, Feature576, Feature356, Feature648, Feature477, Feature261, Feature100, Feature670, Feature226
# 	   Feature570, Feature298, Feature436, Feature491, Feature429, Feature74, Feature282, Feature620, Feature194, Feature495
# Negative:  Feature297, Feature42, Feature582, Feature18, Feature608, Feature236, Feature394, Feature426, Feature116, Feature133
# 	   Feature311, Feature603, Feature418, Feature325, Feature556, Feature398, Feature516, Feature170, Feature38, Feature243
# 	   Feature496, Feature350, Feature553, Feature435, Feature352, Feature558, Feature560, Feature377, Feature407, Feature414
# PC_ 4
# Positive:  Feature2, Feature155, Feature103, Feature458, Feature46, Feature588, Feature22, Feature60, Feature665, Feature175
# 	   Feature461, Feature554, Feature283, Feature268, Feature567, Feature462, Feature545, Feature80, Feature359, Feature373
# 	   Feature557, Feature444, Feature48, Feature539, Feature3, Feature168, Feature592, Feature426, Feature543, Feature656
# Negative:  Feature617, Feature650, Feature365, Feature569, Feature205, Feature28, Feature526, Feature381, Feature150, Feature363
# 	   Feature612, Feature139, Feature214, Feature341, Feature352, Feature92, Feature565, Feature61, Feature275, Feature316
# 	   Feature84, Feature440, Feature284, Feature642, Feature419, Feature15, Feature200, Feature575, Feature72, Feature112
# PC_ 5
# Positive:  Feature420, Feature494, Feature402, Feature283, Feature351, Feature365, Feature569, Feature328, Feature392, Feature240
# 	   Feature481, Feature570, Feature643, Feature375, Feature40, Feature64, Feature625, Feature84, Feature372, Feature38
# 	   Feature568, Feature455, Feature499, Feature92, Feature636, Feature150, Feature191, Feature426, Feature15, Feature511
# Negative:  Feature72, Feature125, Feature652, Feature17, Feature196, Feature99, Feature571, Feature275, Feature336, Feature197
# 	   Feature659, Feature592, Feature575, Feature377, Feature352, Feature9, Feature535, Feature669, Feature132, Feature350
# 	   Feature165, Feature2, Feature170, Feature253, Feature205, Feature398, Feature440, Feature236, Feature642, Feature22
#
# Warning message:
# “Key ‘PC_’ taken, using ‘spca_’ instead”
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
# [1] 1
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
# [1] 2
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
# [1] 3
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# Normalizing layer: counts
#
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  Fe
# 	   Feature1841, Feature1005, Feature1229, Feature1394, Feature885, Feature261, Feature197, Feature408, Feature1911, Feature1401
# Negative:  Feature882, Feature97, Feature1651, Feature41, Feature1223, Feature690, Feature1133, Feature394, Feature1571, Feature1729
# 	   Feature959, Feature309, Feature933, Feature515, Feature1565, Feature1469, Feature1141, Feature709, Feature1404, Feature1576
# 	   Feature83, Feature1721, Feature1189, Feature1323, Feature1177, Feature449, Feature1242, Feature1019, Feature1797, Feature1135
# PC_ 4
# Positive:  Feature834, Feature1400, Feature1077, Feature1022, Feature1149, Feature962, Feature1911, Feature1621, Feature1223, Feature1203
# 	   Feature1004, Feature1082, Feature1780, Feature1, Feature91, Feature1414, Feature3, Feature1305, Feature466, Feature665
# 	   Feature269, Feature365, Feature1314, Feature552, Feature111, Feature727, Feature168, Feature171, Feature954, Feature1399
# Negative:  Feature192, Feature816, Feature38, Feature1023, Feature591, Feature593, Feature614, Feature1632, Feature1087, Feature515
# 	   Feature58, Feature342, Feature1141, Feature260, Feature1868, Feature42, Feature366, Feature1828, Feature1200, Feature487
# 	   Feature1189, Feature1255, Feature747, Feature1924, Feature1346, Feature983, Feature149, Feature835, Feature690, Feature1622
# PC_ 5
# Positive:  Feature3, Feature466, Feature53, Feature269, Feature1695, Feature1314, Feature1849, Feature342, Feature1322, Feature111
# 	   Feature1684, Feature1263, Feature897, Feature737, Feature1901, Feature157, Feature1162, Feature1567, Feature1339, Feature544
# 	   Feature1327, Feature1622, Feature781, Feature213, Feature70, Feature689, Feature1520, Feature1354, Feature38, Feature1078
# Negative:  Feature1056, Feature1620, Feature237, Feature697, Feature1129, Feature1203, Feature1370, Feature218, Feature1763, Feature31
# 	   Feature1831, Feature1844, Feature453, Feature1149, Feature962, Feature83, Feature582, Feature163, Feature634, Feature1495
# 	   Feature172, Feature1737, Feature1082, Feature1418, Feature826, Feature1610, Feature309, Feature1813, Feature1400, Feature1637
#
# Warning message:
# “Key ‘PC_’ taken, using ‘spca_’ instead”
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
# [1] 1
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
# [1] 2
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
# [1] 3
#   Method     Clustering   Matrices Hyperparam HVGs Data ARI       AMI
# 1 WNN-Leiden 3, 3, 4,.... U,S      0.75       357  cl5  0.7630633 0.7244586
# 2 WNN-Leiden 2, 2, 4,.... U,S      1.00       357  cl5  0.5834477 0.6410981
# 3 WNN-Leiden 6, 6, 3,.... U,S      1.50       357  cl5  0.5008523 0.5927889
# 4 WNN-Leiden 5, 5, 9,.... U,S      2.00       357  cl5  0.4045409 0.5501903
# 5 WNN-Leiden 3, 3, 4,.... U,S      0.75       357  cl5  0.7630633 0.7244586
# 6 WNN-Leiden 2, 2, 4,.... U,S      1.00       357  cl5  0.5834477 0.6410981

# %%
xy
# Out:
#    Method     Clustering   Matrices Hyperparam HVGs Data            ARI
# 1  WNN-Leiden 3, 3, 4,.... U,S      0.75        357 cl5             0.7630633
# 2  WNN-Leiden 2, 2, 4,.... U,S      1.00        357 cl5             0.5834477
# 3  WNN-Leiden 6, 6, 3,.... U,S      1.50        357 cl5             0.5008523
# 4  WNN-Leiden 5, 5, 9,.... U,S      2.00        357 cl5             0.4045409
# 5  WNN-Leiden 3, 3, 4,.... U,S      0.75        357 cl5             0.7630633
# 6  WNN-Leiden 2, 2, 4,.... U,S      1.00        357 cl5             0.5834477
# 7  WNN-Leiden 6, 6, 3,.... U,S      1.50        357 cl5             0.5008523
# 8  WNN-Leiden 5, 5, 9,.... U,S      2.00        357 cl5             0.4045409
# 9  WNN-Leiden 3, 3, 4,.... U,S      0.75        357 cl5             0.7630633
# 10 WNN-Leiden 2, 2, 4,.... U,S      1.00        357 cl5             0.5834477
# 11 WNN-Leiden 6, 6, 3,.... U,S      1.50        357 cl5             0.5008523
# 12 WNN-Leiden 5, 5, 9,.... U,S      2.00        357 cl5             0.4045409
# 13 WNN-Leiden 2, 2, 3,.... U,S      0.75       1193 cl5             0.6311314
# 14 WNN-Leiden 2, 2, 3,.... U,S      1.00       1193 cl5             0.5745068
# 15 WNN-Leiden 7, 7, 9,.... U,S      1.50       1193 cl5             0.4021076
# 16 WNN-Leiden 7, 7, 9,.... U,S      2.00       1193 cl5             0.4032356
# 17 WNN-Leiden 2, 2, 3,.... U,S      0.75       1193 cl5             0.6311314
# 18 WNN-Leiden 2, 2, 3,.... U,S      1.00       1193 cl5             0.5745068
# 19 WNN-Leiden 7, 7, 9,.... U,S      1.50       1193 cl5             0.4021076
# 20 WNN-Leiden 7, 7, 9,.... U,S      2.00       1193 cl5             0.4032356
# 21 WNN-Leiden 2, 2, 3,.... U,S      0.75       1193 cl5             0.6311314
# 22 WNN-Leiden 2, 2, 3,.... U,S      1.00       1193 cl5             0.5745068
# 23 WNN-Leiden 7, 7, 9,.... U,S      1.50       1193 cl5             0.4021076
# 24 WNN-Leiden 7, 7, 9,.... U,S      2.00       1193 cl5             0.4032356
# 25 WNN-Leiden 15, 2, 2.... U,S      0.75        359 allen_b02h01a02 0.4270250
# 26 WNN-Leiden 17, 8, 4.... U,S      1.00        359 allen_b02h01a02 0.3329612
# 27 WNN-Leiden 15, 7, 4.... U,S      1.50        359 allen_b02h01a02 0.3184427
# 28 WNN-Leiden 15, 7, 3.... U,S      2.00        359 allen_b02h01a02 0.2993651
# 29 WNN-Leiden 15, 2, 2.... U,S      0.75        359 allen_b02h01a02 0.4270250
# 30 WNN-Leiden 17, 8, 4.... U,S      1.00        359 allen_b02h01a02 0.3329612
# ⋮  ⋮          ⋮            ⋮        ⋮          ⋮    ⋮               ⋮
# 67 WNN-Leiden 23, 4, 4.... U,S      1.50       2770 allen_b02h01a02 0.3122357
# 68 WNN-Leiden 24, 3, 3.... U,S      2.00       2770 allen_b02h01a02 0.2882407
# 69 WNN-Leiden 17, 2, 2.... U,S      0.75       2770 allen_b02h01a02 0.4401946
# 70 WNN-Leiden 22, 4, 4.... U,S      1.00       2770 allen_b02h01a02 0.3246112
# 71 WNN-Leiden 23, 4, 4.... U,S      1.50       2770 allen_b02h01a02 0.3122357
# 72 WNN-Leiden 24, 3, 3.... U,S      2.00       2770 allen_b02h01a02 0.2882407
# 73 WNN-Leiden 2, 6, 6,.... U,S      0.75       1137 cl3             0.5736580
# 74 WNN-Leiden 1, 5, 5,.... U,S      1.00       1137 cl3             0.4791626
# 75 WNN-Leiden 9, 5, 5,.... U,S      1.50       1137 cl3             0.4416349
# 76 WNN-Leiden 9, 5, 5,.... U,S      2.00       1137 cl3             0.4217886
# 77 WNN-Leiden 2, 6, 6,.... U,S      0.75       1137 cl3             0.5736580
# 78 WNN-Leiden 1, 5, 5,.... U,S      1.00       1137 cl3             0.4791626
# 79 WNN-Leiden 9, 5, 5,.... U,S      1.50       1137 cl3             0.4416349
# 80 WNN-Leiden 9, 5, 5,.... U,S      2.00       1137 cl3             0.4217886
# 81 WNN-Leiden 2, 6, 6,.... U,S      0.75       1137 cl3             0.5736580
# 82 WNN-Leiden 1, 5, 5,.... U,S      1.00       1137 cl3             0.4791626
# 83 WNN-Leiden 9, 5, 5,.... U,S      1.50       1137 cl3             0.4416349
# 84 WNN-Leiden 9, 5, 5,.... U,S      2.00       1137 cl3             0.4217886
# 85 WNN-Leiden 3, 2, 9,.... U,S      0.75       1948 allen_b08       0.4740499
# 86 WNN-Leiden 5, 1, 10.... U,S      1.00       1948 allen_b08       0.4005428
# 87 WNN-Leiden 13, 10, .... U,S      1.50       1948 allen_b08       0.2721928
# 88 WNN-Leiden 16, 9, 1.... U,S      2.00       1948 allen_b08       0.2135562
# 89 WNN-Leiden 3, 2, 9,.... U,S      0.75       1948 allen_b08       0.4740499
# 90 WNN-Leiden 5, 1, 10.... U,S      1.00       1948 allen_b08       0.4005428
# 91 WNN-Leiden 13, 10, .... U,S      1.50       1948 allen_b08       0.2721928
# 92 WNN-Leiden 16, 9, 1.... U,S      2.00       1948 allen_b08       0.2135562
# 93 WNN-Leiden 3, 2, 9,.... U,S      0.75       1948 allen_b08       0.4740499
# 94 WNN-Leiden 5, 1, 10.... U,S      1.00       1948 allen_b08       0.4005428
# 95 WNN-Leiden 13, 10, .... U,S      1.50       1948 allen_b08       0.2721928
# 96 WNN-Leiden 16, 9, 1.... U,S      2.00       1948 allen_b08       0.2135562
#    AMI
# 1  0.7244586
# 2  0.6410981
# 3  0.5927889
# 4  0.5501903
# 5  0.7244586
# 6  0.6410981
# 7  0.5927889
# 8  0.5501903
# 9  0.7244586
# 10 0.6410981
# 11 0.5927889
# 12 0.5501903
# 13 0.6689579
# 14 0.6382897
# 15 0.5507336
# 16 0.5526570
# 17 0.6689579
# 18 0.6382897
# 19 0.5507336
# 20 0.5526570
# 21 0.6689579
# 22 0.6382897
# 23 0.5507336
# 24 0.5526570
# 25 0.6174465
# 26 0.5786508
# 27 0.5644617
# 28 0.5521181
# 29 0.6174465
# 30 0.5786508
# ⋮  ⋮
# 67 0.5525899
# 68 0.5368365
# 69 0.6119614
# 70 0.5595110
# 71 0.5525899
# 72 0.5368365
# 73 0.6038817
# 74 0.5308237
# 75 0.5060537
# 76 0.4912854
# 77 0.6038817
# 78 0.5308237
# 79 0.5060537
# 80 0.4912854
# 81 0.6038817
# 82 0.5308237
# 83 0.5060537
# 84 0.4912854
# 85 0.6607463
# 86 0.6035977
# 87 0.5212141
# 88 0.4891360
# 89 0.6607463
# 90 0.6035977
# 91 0.5212141
# 92 0.4891360
# 93 0.6607463
# 94 0.6035977
# 95 0.5212141
# 96 0.4891360

# %% [markdown]
# ## **Run on simulation data**

# %%
looms <- c('./home/tchari/counts/meKMeans_sims/loom/negctrl_sim_k1.loom',
 './home/tchari/counts/meKMeans_sims/loom/b_beta_sim_k8.loom',
 './home/tchari/counts/meKMeans_sims/loom/k_gamma_sim_k8.loom')

#'allen_b08', 'allen_b02h01', 'cl3', 'cl5', 'brca1', 'pbmc','e11e13'
shorts <- c('negctrl_sim_k1','b_beta_sim_k8','k_gamma_sim_k8')

# %% [markdown]
# ### **MOFA2**

# %%
res <- 1
xy <- vector("list", num_runs*2*length(shorts)) # create an empty list into which values are to be filled
ind <- 0

for (o in 1:length(looms)){
    a08 <- Connect(filename = looms[o], mode = "r")
    
    
    # gene list
    n_genes <- a08[['row_attrs']][['gene_name']][['dims']]
    gns <- a08[['row_attrs']][['gene_name']][1:n_genes]
    
    # cell ID list
    n_cells <- a08[['col_attrs']][['barcode']][['dims']]
    cellids <- a08[['col_attrs']][['barcode']][1:n_cells]
    celllabs <- a08[['col_attrs']][['subclass_label']][1:n_cells]
    
    # get raw counts matrix
    raw.cnts <- t(a08[["layers/unspliced"]][,])
    colnames(raw.cnts) <- cellids
    # rownames(raw.cnts) <- gns
    
    
    metadata <- data.frame(
        cellID = cellids
        )
    rownames(metadata) <- cellids
    
    
    
    s_obj <- CreateSeuratObject(counts = raw.cnts,
                                project = "fromLoom",
                                assay = "URNA",
                                meta.data = metadata)
    
    sraw.cnts <- t(a08[["layers/spliced"]][,])
    colnames(sraw.cnts) <- cellids

    a08$close_all()

    num_features <- nrow(s_obj)
    print(looms[o])
    
    for (nr in 1:num_runs){
        # --- Running MOFA2 -----
        MOFAobject <- create_mofa(list(raw.cnts,sraw.cnts))
        data_opts <- get_default_data_options(MOFAobject)
        data_opts$scale_views <- TRUE
        model_opts <- get_default_model_options(MOFAobject)
        train_opts <- get_default_training_options(MOFAobject)
    
        MOFAobject <- prepare_mofa(
          object = MOFAobject,
          data_options = data_opts,
          model_options = model_opts,
          training_options = train_opts
        )
        outfile = file.path(getwd(),"model.hdf5")
        MOFAobject.trained <- run_mofa(MOFAobject, outfile)
        
        model <- load_model(outfile)
    
        factors <- get_factors(model)$group1
    
    
        pca_embeddings_mofa <- factors
        rownames(pca_embeddings_mofa) <- colnames(s_obj)
        colnames(pca_embeddings_mofa) <- colnames(factors)
        s_obj[["test"]] <- CreateDimReducObject(embeddings = as.matrix(pca_embeddings_mofa), key='Factor', assay = 'URNA')
        
        s_obj <- FindNeighbors(s_obj,reduction = 'test',graph.name = 'mofa',dims =1:dim(factors)[2])
    
        
        #Get leiden clusters for different res
        s_obj <- FindClusters(s_obj,graph.name='mofa',  algorithm = 4, resolution = res, verbose = FALSE, cluster.name='leiden')
        ind <- ind+1
        xy[[ind]] <- data.frame(Method = 'MOFA2-Leiden',
                            Clustering = I(list(s_obj[['leiden']]$leiden)),
                            Matrices = 'U,S',
                            Hyperparam = res,
                            HVGs = num_features ,
                            Data = shorts[o],
                            ARI = ARI(celllabs,s_obj[['leiden']]$leiden),
                            AMI = AMI(celllabs,s_obj[['leiden']]$leiden))

        print(ARI(celllabs,s_obj[['leiden']]$leiden))
    
    
        if (grepl('negctrl', looms[o], fixed = TRUE)){
            k <- length(unique(s_obj[['leiden']]$leiden)) 
        }
        else{
            k <- length(unique(celllabs))
        }
        d <- cluster_samples(model, k=k)

        ind <- ind+1
        xy[[ind]] <- data.frame(Method = 'MOFA2-K-Means',
                            Clustering = paste(d$cluster,collapse="|"),
                            Matrices = 'U,S',
                            Hyperparam = k,
                            HVGs = num_features ,
                            Data = shorts[o],
                            ARI = ARI(celllabs,d$cluster),
                            AMI = AMI(celllabs,d$cluster))

        print(ARI(celllabs,d$cluster))
    
        # --- Running MOFA2 -----
    }
    

    

}

xy <- do.call(rbind, xy)

xy %>% 
  rowwise() %>% 
  mutate_if(is.list, ~paste(unlist(.), collapse = '|')) %>% 
  write.csv('./fits/Seuratruns_0508/MOFA_sim_results.csv', row.names = FALSE)

head(xy)
#shorts[o]
# Out:
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# [1] "/home/tchari/counts/meKMeans_sims/loom/negctrl_sim_k1.loom"
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message in load_model(outfile):
# “All 20 factors were found to explain little or no variance so remove_inactive_factors option has been disabled.”
# Warning message in .quality_control(object, verbose = verbose):
# “The model contains highly correlated factors (see `plot_factor_cor(MOFAobject)`).
# We recommend that you train the model with less factors and that you let it train for a longer time.
# ”
# Warning message in load_model(outfile):
# “All 20 factors were found to explain little or no variance so remove_inactive_factors option has been disabled.”
# Warning message in .quality_control(object, verbose = verbose):
# “The model contains highly correlated factors (see `plot_factor_cor(MOFAobject)`).
# We recommend that you train the model with less factors and that you let it train for a longer time.
# ”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0
# [1] 0
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message in load_model(outfile):
# “All 20 factors were found to explain little or no variance so remove_inactive_factors option has been disabled.”
# Warning message in .quality_control(object, verbose = verbose):
# “The model contains highly correlated factors (see `plot_factor_cor(MOFAobject)`).
# We recommend that you train the model with less factors and that you let it train for a longer time.
# ”
# Warning message in load_model(outfile):
# “All 20 factors were found to explain little or no variance so remove_inactive_factors option has been disabled.”
# Warning message in .quality_control(object, verbose = verbose):
# “The model contains highly correlated factors (see `plot_factor_cor(MOFAobject)`).
# We recommend that you train the model with less factors and that you let it train for a longer time.
# ”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0
# [1] 0
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# Warning message in load_model(outfile):
# “All 20 factors were found to explain little or no variance so remove_inactive_factors option has been disabled.”
# Warning message in .quality_control(object, verbose = verbose):
# “The model contains highly correlated factors (see `plot_factor_cor(MOFAobject)`).
# We recommend that you train the model with less factors and that you let it train for a longer time.
# ”
# Warning message in load_model(outfile):
# “All 20 factors were found to explain little or no variance so remove_inactive_factors option has been disabled.”
# Warning message in .quality_control(object, verbose = verbose):
# “The model contains highly correlated factors (see `plot_factor_cor(MOFAobject)`).
# We recommend that you train the model with less factors and that you let it train for a longer time.
# ”
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0
# [1] 0
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# [1] "/home/tchari/counts/meKMeans_sims/loom/b_beta_sim_k8.loom"
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# 7 factors were found to explain no variance and they were removed for downstream analysis. You can disable this option by setting load_model(..., remove_inactive_factors = FALSE)
#
# 7 factors were found to explain no variance and they were removed for downstream analysis. You can disable this option by setting load_model(..., remove_inactive_factors = FALSE)
#
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 1
# [1] 0.8611466
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# 7 factors were found to explain no variance and they were removed for downstream analysis. You can disable this option by setting load_model(..., remove_inactive_factors = FALSE)
#
# 7 factors were found to explain no variance and they were removed for downstream analysis. You can disable this option by setting load_model(..., remove_inactive_factors = FALSE)
#
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 1
# [1] 0.9724933
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# 7 factors were found to explain no variance and they were removed for downstream analysis. You can disable this option by setting load_model(..., remove_inactive_factors = FALSE)
#
# 7 factors were found to explain no variance and they were removed for downstream analysis. You can disable this option by setting load_model(..., remove_inactive_factors = FALSE)
#
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 1
# [1] 1
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# [1] "/home/tchari/counts/meKMeans_sims/loom/k_gamma_sim_k8.loom"
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# 15 factors were found to explain no variance and they were removed for downstream analysis. You can disable this option by setting load_model(..., remove_inactive_factors = FALSE)
#
# 15 factors were found to explain no variance and they were removed for downstream analysis. You can disable this option by setting load_model(..., remove_inactive_factors = FALSE)
#
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.4418632
# [1] 1
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# 15 factors were found to explain no variance and they were removed for downstream analysis. You can disable this option by setting load_model(..., remove_inactive_factors = FALSE)
#
# 15 factors were found to explain no variance and they were removed for downstream analysis. You can disable this option by setting load_model(..., remove_inactive_factors = FALSE)
#
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.4418632
# [1] 0.5670456
# Creating MOFA object from a list of matrices (features as rows, sample as columns)...
#
#
# View names are not specified in the data, using default: view_1, view_2
#
#
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 1, using default: feature1_v1, feature2_v1...”
# Warning message in create_mofa_from_matrix(data, groups):
# “Feature names are not specified for view 2, using default: feature1_v2, feature2_v2...”
# Checking data options...
#
# Checking training options...
#
# Checking model options...
#
# Warning: Output file /home/tchari/perturbCME/notebooks/model.hdf5 already exists, it will be replaced
#
# Connecting to the mofapy2 python package using reticulate (use_basilisk = FALSE)...
#     Please make sure to manually specify the right python binary when loading R with reticulate::use_python(..., force=TRUE) or the right conda environment with reticulate::use_condaenv(..., force=TRUE)
#     If you prefer to let us automatically install a conda environment with 'mofapy2' installed using the 'basilisk' package, please use the argument 'use_basilisk = TRUE'
#
#
# Warning message in run_mofa(MOFAobject, outfile):
# “The latest mofapy2 version is 0.7.0, you are using 0.7.1. Please upgrade with 'pip install mofapy2'”
# 15 factors were found to explain no variance and they were removed for downstream analysis. You can disable this option by setting load_model(..., remove_inactive_factors = FALSE)
#
# 15 factors were found to explain no variance and they were removed for downstream analysis. You can disable this option by setting load_model(..., remove_inactive_factors = FALSE)
#
# Warning message:
# “Keys should be one or more alphanumeric characters followed by an underscore, setting key from Factor to Factor_”
# Computing nearest neighbor graph
#
# Computing SNN
#
# Only one graph name supplied, storing nearest-neighbor graph only
# [1] 0.4418632
# [1] 0.8036055
#   Method        Clustering   Matrices Hyperparam HVGs Data           ARI AMI
# 1 MOFA2-Leiden  10, 7, 1.... U,S       1         1100 negctrl_sim_k1 0   0
# 2 MOFA2-K-Means 12|1|12|.... U,S      21         1100 negctrl_sim_k1 0   0
# 3 MOFA2-Leiden  10, 7, 1.... U,S       1         1100 negctrl_sim_k1 0   0
# 4 MOFA2-K-Means 19|4|5|1.... U,S      21         1100 negctrl_sim_k1 0   0
# 5 MOFA2-Leiden  10, 7, 1.... U,S       1         1100 negctrl_sim_k1 0   0
# 6 MOFA2-K-Means 1|19|20|.... U,S      21         1100 negctrl_sim_k1 0   0

# %%
xy
# Out:
#    Method        Clustering   Matrices Hyperparam HVGs Data           ARI
# 1  MOFA2-Leiden  10, 7, 1.... U,S       1         1100 negctrl_sim_k1 0.0000000
# 2  MOFA2-K-Means 12|1|12|.... U,S      21         1100 negctrl_sim_k1 0.0000000
# 3  MOFA2-Leiden  10, 7, 1.... U,S       1         1100 negctrl_sim_k1 0.0000000
# 4  MOFA2-K-Means 19|4|5|1.... U,S      21         1100 negctrl_sim_k1 0.0000000
# 5  MOFA2-Leiden  10, 7, 1.... U,S       1         1100 negctrl_sim_k1 0.0000000
# 6  MOFA2-K-Means 1|19|20|.... U,S      21         1100 negctrl_sim_k1 0.0000000
# 7  MOFA2-Leiden  9, 9, 9,.... U,S       1         1100 b_beta_sim_k8  1.0000000
# 8  MOFA2-K-Means 7|7|7|7|.... U,S      10         1100 b_beta_sim_k8  0.8611466
# 9  MOFA2-Leiden  9, 9, 9,.... U,S       1         1100 b_beta_sim_k8  1.0000000
# 10 MOFA2-K-Means 1|1|1|1|.... U,S      10         1100 b_beta_sim_k8  0.9724933
# 11 MOFA2-Leiden  9, 9, 9,.... U,S       1         1100 b_beta_sim_k8  1.0000000
# 12 MOFA2-K-Means 7|7|7|7|.... U,S      10         1100 b_beta_sim_k8  1.0000000
# 13 MOFA2-Leiden  10, 10, .... U,S       1          700 k_gamma_sim_k8 0.4418632
# 14 MOFA2-K-Means 1|1|1|1|.... U,S       5          700 k_gamma_sim_k8 1.0000000
# 15 MOFA2-Leiden  10, 10, .... U,S       1          700 k_gamma_sim_k8 0.4418632
# 16 MOFA2-K-Means 2|2|2|2|.... U,S       5          700 k_gamma_sim_k8 0.5670456
# 17 MOFA2-Leiden  10, 10, .... U,S       1          700 k_gamma_sim_k8 0.4418632
# 18 MOFA2-K-Means 1|1|1|1|.... U,S       5          700 k_gamma_sim_k8 0.8036055
#    AMI
# 1  0.0000000
# 2  0.0000000
# 3  0.0000000
# 4  0.0000000
# 5  0.0000000
# 6  0.0000000
# 7  1.0000000
# 8  0.9167031
# 9  1.0000000
# 10 0.9659187
# 11 1.0000000
# 12 1.0000000
# 13 0.5923224
# 14 1.0000000
# 15 0.5923224
# 16 0.7723985
# 17 0.5923224
# 18 0.7870005

# %% [markdown]
# ### **WNN**

# %%
res <- c(0.75,1,1.5,2)
xy <- vector("list", num_runs*length(res)*length(shorts)) # create an empty list into which values are to be filled

ind <- 0
for (o in 1:length(looms)){
    a08 <- Connect(filename = looms[o], mode = "r")
    
    
    # gene list
    n_genes <- a08[['row_attrs']][['gene_name']][['dims']]
    gns <- a08[['row_attrs']][['gene_name']][1:n_genes]
    
    # cell ID list
    n_cells <- a08[['col_attrs']][['barcode']][['dims']]
    cellids <- a08[['col_attrs']][['barcode']][1:n_cells]
    celllabs <- a08[['col_attrs']][['subclass_label']][1:n_cells]
    
    # get raw counts matrix
    raw.cnts <- t(a08[["layers/unspliced"]][,])
    colnames(raw.cnts) <- cellids
    # rownames(raw.cnts) <- gns
    
    
    metadata <- data.frame(
        cellID = cellids
        )
    rownames(metadata) <- cellids
    
    
    
    s_obj <- CreateSeuratObject(counts = raw.cnts,
                                project = "fromLoom",
                                assay = "URNA",
                                meta.data = metadata)
    
    sraw.cnts <- t(a08[["layers/spliced"]][,])
    colnames(sraw.cnts) <- cellids
    
    s_assay <- CreateAssay5Object(counts = sraw.cnts)
    
    s_obj[["SRNA"]] <- s_assay
    
    a08$close_all()
    
    DefaultAssay(s_obj) <- 'URNA'
    s_obj <- NormalizeData(s_obj) 
    # s_obj <- FindVariableFeatures(s_obj) 
    s_obj <- ScaleData(s_obj) 
    s_obj <- RunPCA(s_obj,reduction.name = 'upca', features = Features(s_obj))
    
    DefaultAssay(s_obj) <- 'SRNA'
    s_obj <- NormalizeData(s_obj) 
    # s_obj <- FindVariableFeatures(s_obj)
    s_obj <- ScaleData(s_obj)
    s_obj <- RunPCA(s_obj,reduction.name = 'spca',features = Features(s_obj))
    
    for (nr in 1:num_runs){
        s_obj <- FindMultiModalNeighbors(
          s_obj, reduction.list = list("upca", "spca"), 
          dims.list = list(1:30, 1:30), modality.weight.name = "RNA.weight"
        )
        
        #Run Leiden here + save results
        num_features <- nrow(s_obj)
        
        
        for (i in 1:length(res)) {
          #Get leiden clusters for different res
          s_obj <- FindClusters(s_obj, graph.name = "wsnn", algorithm = 4, resolution = res[i], verbose = FALSE, cluster.name='leiden')
          ind <- ind + 1
          xy[[ind]] <- data.frame(Method = 'WNN-Leiden',
                                Clustering = I(list(s_obj[['leiden']]$leiden)),
                                Matrices = 'U,S',
                                Hyperparam = res[i],
                                HVGs = num_features ,
                                Data = shorts[o],
                                ARI = ARI(celllabs,s_obj[['leiden']]$leiden),
                                AMI = AMI(celllabs,s_obj[['leiden']]$leiden))
        }
    }

}

xy <- do.call(rbind, xy)

xy %>% 
  rowwise() %>% 
  mutate_if(is.list, ~paste(unlist(.), collapse = '|')) %>% 
  write.csv('./fits/Seuratruns_0508/WNN_sim_results.csv', row.names = FALSE)
  #write.csv('./fits/Seuratruns_0306/WNN_sim_results.csv', row.names = FALSE)

head(xy)
#shorts[o]
# Out:
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# Normalizing layer: counts
#
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  Feature523, Feature488, Feature73, Feature1090, Feature6, Feature1075, Feature373, Feature987, Feature1053, Feature376
# 	   Feature187, Feature557, Feature930, Feature1015, Feature514, Feature863, Feature399, Feature1007, Feature50, Feature207
# 	   Feature483, Feature823, Feature305, Feature267, Feature674, Feature289, Feature610, Feature511, Feature502, Feature255
# Negative:  Feature1024, Feature326, Feature499, Feature538, Feature120, Feature653, Feature847, Feature714, Feature119, Feature370
# 	   Feature195, Feature729, Feature703, Feature3, Feature52, Feature965, Feature678, Feature336, Feature84, Feature783
# 	   Feature1048, Feature713, Feature513, Feature81, Feature923, Feature34, Feature615, Feature113, Feature311, Feature582
# PC_ 2
# Positive:  Feature55, Feature188, Feature408, Feature871, Feature534, Feature808, Feature581, Feature468, Feature223, Feature73
# 	   Feature365, Feature373, Feature454, Feature959, Feature681, Feature489, Feature32, Feature127, Feature651, Feature628
# 	   Feature782, Feature552, Feature1036, Feature707, Feature406, Feature344, Feature618, Feature464, Feature784, Feature696
# Negative:  Feature76, Feature9, Feature837, Feature630, Feature954, Feature589, Feature53, Feature963, Feature316, Feature367
# 	   Feature643, Feature113, Feature133, Feature264, Feature1064, Feature958, Feature485, Feature10, Feature1001, Feature176
# 	   Feature411, Feature623, Feature912, Feature781, Feature394, Feature785, Feature251, Feature377, Feature894, Feature905
# PC_ 3
# Positive:  Feature199, Feature473, Feature289, Feature194, Feature814, Feature715, Feature236, Feature921, Feature682, Feature270
# 	   Feature711, Feature871, Feature916, Feature69, Feature1022, Feature556, Feature303, Feature862, Feature486, Feature55
# 	   Feature609, Feature359, Feature120, Feature887, Feature1009, Feature1063, Feature302, Feature102, Feature700, Feature1067
# Negative:  Feature746, Feature131, Feature803, Feature29, Feature405, Feature434, Feature572, Feature366, Feature758, Feature1002
# 	   Feature1034, Feature525, Feature578, Feature22, Feature345, Feature1098, Feature296, Feature252, Feature2, Feature621
# 	   Feature1012, Feature592, Feature391, Feature397, Feature167, Feature466, Feature590, Feature460, Feature783, Feature32
# PC_ 4
# Positive:  Feature604, Feature861, Feature633, Feature279, Feature551, Feature401, Feature342, Feature514, Feature1081, Feature697
# 	   Feature180, Feature789, Feature932, Feature391, Feature769, Feature713, Feature891, Feature1064, Feature550, Feature1013
# 	   Feature420, Feature628, Feature363, Feature229, Feature434, Feature165, Feature489, Feature896, Feature281, Feature396
# Negative:  Feature782, Feature246, Feature1007, Feature602, Feature24, Feature685, Feature29, Feature1084, Feature287, Feature812
# 	   Feature376, Feature1052, Feature661, Feature619, Feature356, Feature22, Feature876, Feature984, Feature894, Feature265
# 	   Feature91, Feature156, Feature635, Feature70, Feature52, Feature225, Feature682, Feature124, Feature505, Feature113
# PC_ 5
# Positive:  Feature557, Feature53, Feature566, Feature310, Feature109, Feature974, Feature334, Feature270, Feature666, Feature145
# 	   Feature426, Feature520, Feature604, Feature154, Feature690, Feature1067, Feature113, Feature170, Feature683, Feature1084
# 	   Feature40, Feature744, Feature228, Feature420, Feature257, Feature562, Feature802, Feature291, Feature389, Feature1088
# Negative:  Feature282, Feature1008, Feature706, Feature395, Feature766, Feature249, Feature222, Feature272, Feature911, Feature885
# 	   Feature119, Feature11, Feature702, Feature556, Feature220, Feature959, Feature564, Feature941, Feature354, Feature938
# 	   Feature782, Feature1000, Feature742, Feature548, Feature55, Feature928, Feature882, Feature1085, Feature740, Feature303
#
# Normalizing layer: counts
#
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  Feature3, Feature1087, Feature873, Feature811, Feature216, Feature712, Feature24, Feature8, Feature122, Feature545
# 	   Feature118, Feature135, Feature633, Feature443, Feature59, Feature226, Feature148, Feature886, Feature172, Feature917
# 	   Feature567, Feature999, Feature338, Feature795, Feature551, Feature559, Feature335, Feature661, Feature756, Feature932
# Negative:  Feature931, Feature535, Feature466, Feature883, Feature625, Feature98, Feature542, Feature692, Feature347, Feature77
# 	   Feature989, Feature301, Feature187, Feature729, Feature230, Feature541, Feature324, Feature578, Feature184, Feature363
# 	   Feature737, Feature486, Feature368, Feature453, Feature86, Feature1042, Feature334, Feature30, Feature308, Feature584
# PC_ 2
# Positive:  Feature318, Feature590, Feature617, Feature330, Feature487, Feature173, Feature134, Feature601, Feature696, Feature110
# 	   Feature346, Feature568, Feature125, Feature919, Feature851, Feature1027, Feature256, Feature634, Feature16, Feature178
# 	   Feature368, Feature397, Feature1053, Feature380, Feature1034, Feature784, Feature965, Feature1042, Feature85, Feature770
# Negative:  Feature660, Feature938, Feature183, Feature180, Feature1040, Feature103, Feature413, Feature645, Feature894, Feature1001
# 	   Feature1069, Feature754, Feature51, Feature78, Feature908, Feature692, Feature362, Feature822, Feature990, Feature417
# 	   Feature321, Feature12, Feature895, Feature378, Feature440, Feature296, Feature926, Feature352, Feature639, Feature168
# PC_ 3
# Positive:  Feature581, Feature941, Feature43, Feature249, Feature297, Feature569, Feature1033, Feature670, Feature118, Feature908
# 	   Feature907, Feature416, Feature841, Feature366, Feature80, Feature923, Feature1006, Feature339, Feature827, Feature790
# 	   Feature946, Feature574, Feature508, Feature117, Feature1020, Feature711, Feature847, Feature71, Feature1069, Feature5
# Negative:  Feature928, Feature641, Feature211, Feature899, Feature55, Feature405, Feature218, Feature130, Feature59, Feature738
# 	   Feature226, Feature179, Feature933, Feature530, Feature950, Feature258, Feature999, Feature767, Feature1086, Feature106
# 	   Feature867, Feature986, Feature186, Feature286, Feature173, Feature555, Feature795, Feature400, Feature955, Feature810
# PC_ 4
# Positive:  Feature407, Feature792, Feature40, Feature333, Feature590, Feature1038, Feature893, Feature1007, Feature994, Feature194
# 	   Feature866, Feature1084, Feature420, Feature556, Feature289, Feature939, Feature969, Feature214, Feature257, Feature854
# 	   Feature886, Feature953, Feature801, Feature147, Feature780, Feature644, Feature406, Feature996, Feature1095, Feature339
# Negative:  Feature889, Feature116, Feature1035, Feature490, Feature207, Feature12, Feature132, Feature436, Feature507, Feature561
# 	   Feature1064, Feature952, Feature178, Feature701, Feature789, Feature396, Feature491, Feature133, Feature1045, Feature242
# 	   Feature990, Feature956, Feature864, Feature385, Feature1069, Feature448, Feature762, Feature7, Feature649, Feature474
# PC_ 5
# Positive:  Feature100, Feature983, Feature197, Feature421, Feature145, Feature200, Feature293, Feature779, Feature753, Feature834
# 	   Feature907, Feature60, Feature207, Feature862, Feature339, Feature999, Feature137, Feature520, Feature1001, Feature705
# 	   Feature1036, Feature12, Feature77, Feature348, Feature67, Feature63, Feature688, Feature548, Feature459, Feature160
# Negative:  Feature788, Feature422, Feature14, Feature875, Feature363, Feature177, Feature611, Feature588, Feature379, Feature1091
# 	   Feature485, Feature635, Feature409, Feature232, Feature837, Feature997, Feature1053, Feature144, Feature804, Feature15
# 	   Feature914, Feature312, Feature264, Feature174, Feature769, Feature111, Feature585, Feature498, Feature1089, Feature480
#
# Warning message:
# “Key ‘PC_’ taken, using ‘spca_’ instead”
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
#
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
#
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
#
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# Normalizing layer: counts
#
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  Feature735, Feature839, Feature139, Feature680, Feature690, Feature152, Feature1091, Feature920, Feature971, Feature832
# 	   Feature263, Feature884, Feature1081, Feature652, Feature1032, Feature732, Feature206, Feature432, Feature694, Feature706
# 	   Feature927, Feature838, Feature900, Feature835, Feature503, Feature213, Feature306, Feature455, Feature616, Feature19
# Negative:  Feature848, Feature530, Feature872, Feature9, Feature391, Feature1066, Feature851, Feature906, Feature168, Feature446
# 	   Feature64, Feature777, Feature282, Feature669, Feature556, Feature547, Feature1012, Feature66, Feature542, Feature546
# 	   Feature205, Feature378, Feature264, Feature893, Feature878, Feature881, Feature836, Feature627, Feature238, Feature783
# PC_ 2
# Positive:  Feature627, Feature1012, Feature542, Feature64, Feature881, Feature1019, Feature893, Feature238, Feature546, Feature370
# 	   Feature1005, Feature112, Feature878, Feature203, Feature172, Feature778, Feature718, Feature1075, Feature287, Feature128
# 	   Feature623, Feature408, Feature175, Feature244, Feature645, Feature29, Feature663, Feature1027, Feature780, Feature253
# Negative:  Feature848, Feature530, Feature9, Feature1066, Feature872, Feature446, Feature556, Feature66, Feature391, Feature282
# 	   Feature783, Feature851, Feature547, Feature804, Feature264, Feature669, Feature906, Feature205, Feature777, Feature168
# 	   Feature349, Feature378, Feature312, Feature1072, Feature836, Feature555, Feature251, Feature548, Feature784, Feature942
# PC_ 3
# Positive:  Feature848, Feature627, Feature1012, Feature542, Feature1066, Feature446, Feature530, Feature851, Feature718, Feature778
# 	   Feature64, Feature546, Feature9, Feature128, Feature881, Feature556, Feature1019, Feature282, Feature878, Feature238
# 	   Feature244, Feature112, Feature168, Feature893, Feature804, Feature370, Feature645, Feature547, Feature66, Feature777
# Negative:  Feature1021, Feature214, Feature163, Feature326, Feature143, Feature56, Feature621, Feature523, Feature1071, Feature873
# 	   Feature259, Feature314, Feature666, Feature541, Feature384, Feature641, Feature89, Feature812, Feature516, Feature68
# 	   Feature254, Feature38, Feature736, Feature283, Feature86, Feature562, Feature40, Feature625, Feature358, Feature515
# PC_ 4
# Positive:  Feature852, Feature725, Feature782, Feature62, Feature266, Feature639, Feature60, Feature1037, Feature435, Feature911
# 	   Feature390, Feature271, Feature753, Feature788, Feature938, Feature930, Feature569, Feature830, Feature501, Feature1089
# 	   Feature17, Feature539, Feature553, Feature500, Feature890, Feature684, Feature106, Feature862, Feature975, Feature576
# Negative:  Feature873, Feature326, Feature259, Feature214, Feature1021, Feature56, Feature143, Feature666, Feature541, Feature314
# 	   Feature163, Feature384, Feature1071, Feature523, Feature254, Feature86, Feature89, Feature812, Feature38, Feature621
# 	   Feature68, Feature641, Feature516, Feature562, Feature918, Feature736, Feature283, Feature750, Feature1049, Feature573
# PC_ 5
# Positive:  Feature586, Feature579, Feature795, Feature984, Feature513, Feature509, Feature431, Feature177, Feature1077, Feature932
# 	   Feature894, Feature602, Feature295, Feature726, Feature1006, Feature366, Feature140, Feature460, Feature762, Feature572
# 	   Feature947, Feature392, Feature193, Feature632, Feature34, Feature103, Feature667, Feature421, Feature426, Feature1029
# Negative:  Feature938, Feature639, Feature725, Feature852, Feature271, Feature62, Feature569, Feature56, Feature516, Feature782
# 	   Feature621, Feature390, Feature214, Feature68, Feature60, Feature523, Feature873, Feature326, Feature812, Feature736
# 	   Feature911, Feature254, Feature848, Feature830, Feature753, Feature666, Feature266, Feature844, Feature259, Feature641
#
# Normalizing layer: counts
#
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  Feature604, Feature57, Feature375, Feature706, Feature473, Feature453, Feature584, Feature151, Feature481, Feature363
# 	   Feature316, Feature877, Feature465, Feature951, Feature395, Feature910, Feature883, Feature875, Feature801, Feature139
# 	   Feature631, Feature652, Feature1007, Feature659, Feature838, Feature673, Feature832, Feature152, Feature960, Feature927
# Negative:  Feature275, Feature816, Feature351, Feature780, Feature663, Feature856, Feature470, Feature841, Feature247, Feature244
# 	   Feature670, Feature200, Feature409, Feature88, Feature645, Feature646, Feature1036, Feature988, Feature871, Feature766
# 	   Feature1087, Feature1060, Feature1100, Feature276, Feature408, Feature893, Feature1005, Feature773, Feature1029, Feature203
# PC_ 2
# Positive:  Feature604, Feature841, Feature57, Feature706, Feature816, Feature275, Feature453, Feature584, Feature473, Feature375
# 	   Feature645, Feature670, Feature780, Feature247, Feature663, Feature856, Feature465, Feature801, Feature481, Feature951
# 	   Feature877, Feature244, Feature151, Feature470, Feature1036, Feature363, Feature646, Feature88, Feature395, Feature316
# Negative:  Feature205, Feature942, Feature270, Feature1, Feature998, Feature113, Feature649, Feature414, Feature422, Feature781
# 	   Feature442, Feature104, Feature272, Feature950, Feature809, Feature59, Feature90, Feature597, Feature758, Feature119
# 	   Feature443, Feature289, Feature547, Feature1042, Feature40, Feature851, Feature331, Feature739, Feature3, Feature360
# PC_ 3
# Positive:  Feature205, Feature270, Feature113, Feature1, Feature998, Feature781, Feature414, Feature942, Feature950, Feature442
# 	   Feature272, Feature649, Feature57, Feature604, Feature104, Feature443, Feature453, Feature422, Feature951, Feature151
# 	   Feature473, Feature584, Feature597, Feature481, Feature375, Feature875, Feature883, Feature59, Feature856, Feature363
# Negative:  Feature525, Feature372, Feature106, Feature50, Feature739, Feature97, Feature788, Feature3, Feature228, Feature1039
# 	   Feature926, Feature156, Feature979, Feature990, Feature625, Feature1095, Feature511, Feature989, Feature195, Feature1001
# 	   Feature785, Feature320, Feature486, Feature300, Feature413, Feature886, Feature336, Feature2, Feature480, Feature665
# PC_ 4
# Positive:  Feature156, Feature785, Feature1001, Feature979, Feature195, Feature926, Feature886, Feature320, Feature989, Feature703
# 	   Feature625, Feature990, Feature956, Feature638, Feature93, Feature521, Feature920, Feature936, Feature1071, Feature541
# 	   Feature587, Feature329, Feature360, Feature474, Feature165, Feature27, Feature561, Feature921, Feature32, Feature891
# Negative:  Feature106, Feature50, Feature511, Feature1039, Feature739, Feature372, Feature525, Feature97, Feature1095, Feature788
# 	   Feature228, Feature639, Feature3, Feature580, Feature336, Feature201, Feature2, Feature1031, Feature698, Feature241
# 	   Feature1029, Feature348, Feature684, Feature665, Feature486, Feature532, Feature179, Feature829, Feature496, Feature560
# PC_ 5
# Positive:  Feature889, Feature900, Feature1091, Feature616, Feature609, Feature227, Feature349, Feature818, Feature379, Feature970
# 	   Feature887, Feature52, Feature1082, Feature1003, Feature51, Feature336, Feature591, Feature358, Feature943, Feature836
# 	   Feature775, Feature284, Feature711, Feature923, Feature90, Feature14, Feature364, Feature37, Feature383, Feature464
# Negative:  Feature55, Feature234, Feature886, Feature956, Feature606, Feature1026, Feature287, Feature576, Feature345, Feature1078
# 	   Feature695, Feature748, Feature1005, Feature229, Feature101, Feature412, Feature269, Feature743, Feature255, Feature661
# 	   Feature399, Feature780, Feature274, Feature452, Feature1028, Feature396, Feature688, Feature948, Feature732, Feature405
#
# Warning message:
# “Key ‘PC_’ taken, using ‘spca_’ instead”
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
#
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
#
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
#
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# Normalizing layer: counts
#
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  Feature412, Feature450, Feature304, Feature180, Feature253, Feature501, Feature541, Feature384, Feature326, Feature366
# 	   Feature52, Feature648, Feature484, Feature552, Feature148, Feature377, Feature29, Feature454, Feature121, Feature220
# 	   Feature675, Feature329, Feature585, Feature305, Feature308, Feature86, Feature247, Feature218, Feature663, Feature616
# Negative:  Feature491, Feature260, Feature413, Feature102, Feature346, Feature602, Feature272, Feature387, Feature630, Feature586
# 	   Feature389, Feature208, Feature393, Feature520, Feature316, Feature642, Feature99, Feature221, Feature457, Feature16
# 	   Feature565, Feature530, Feature700, Feature47, Feature256, Feature665, Feature670, Feature203, Feature323, Feature207
# PC_ 2
# Positive:  Feature412, Feature304, Feature552, Feature501, Feature180, Feature648, Feature450, Feature384, Feature220, Feature253
# 	   Feature52, Feature29, Feature616, Feature585, Feature329, Feature366, Feature326, Feature148, Feature541, Feature454
# 	   Feature377, Feature308, Feature413, Feature348, Feature218, Feature121, Feature239, Feature484, Feature398, Feature663
# Negative:  Feature474, Feature447, Feature644, Feature380, Feature244, Feature225, Feature514, Feature49, Feature363, Feature572
# 	   Feature280, Feature618, Feature20, Feature635, Feature562, Feature257, Feature422, Feature264, Feature592, Feature481
# 	   Feature82, Feature62, Feature637, Feature523, Feature654, Feature71, Feature136, Feature353, Feature109, Feature692
# PC_ 3
# Positive:  Feature21, Feature228, Feature265, Feature295, Feature472, Feature440, Feature627, Feature405, Feature640, Feature517
# 	   Feature15, Feature599, Feature624, Feature580, Feature687, Feature574, Feature150, Feature334, Feature486, Feature53
# 	   Feature25, Feature298, Feature125, Feature112, Feature425, Feature529, Feature184, Feature660, Feature365, Feature255
# Negative:  Feature474, Feature225, Feature244, Feature447, Feature644, Feature380, Feature514, Feature572, Feature549, Feature654
# 	   Feature136, Feature592, Feature618, Feature481, Feature523, Feature62, Feature71, Feature635, Feature264, Feature127
# 	   Feature562, Feature363, Feature422, Feature331, Feature353, Feature478, Feature49, Feature154, Feature404, Feature9
# PC_ 4
# Positive:  Feature440, Feature21, Feature128, Feature280, Feature377, Feature478, Feature450, Feature330, Feature105, Feature552
# 	   Feature228, Feature229, Feature549, Feature213, Feature107, Feature388, Feature227, Feature265, Feature429, Feature600
# 	   Feature106, Feature50, Feature365, Feature408, Feature262, Feature523, Feature496, Feature640, Feature484, Feature687
# Negative:  Feature666, Feature157, Feature659, Feature444, Feature120, Feature658, Feature189, Feature576, Feature449, Feature527
# 	   Feature499, Feature332, Feature615, Feature345, Feature236, Feature567, Feature528, Feature7, Feature118, Feature674
# 	   Feature628, Feature371, Feature26, Feature322, Feature22, Feature503, Feature694, Feature374, Feature482, Feature1
# PC_ 5
# Positive:  Feature176, Feature281, Feature255, Feature312, Feature349, Feature569, Feature480, Feature195, Feature243, Feature30
# 	   Feature2, Feature570, Feature613, Feature306, Feature46, Feature104, Feature511, Feature277, Feature656, Feature519
# 	   Feature521, Feature660, Feature424, Feature68, Feature483, Feature242, Feature351, Feature339, Feature564, Feature335
# Negative:  Feature250, Feature76, Feature139, Feature282, Feature685, Feature434, Feature588, Feature95, Feature639, Feature363
# 	   Feature40, Feature299, Feature157, Feature650, Feature77, Feature381, Feature168, Feature151, Feature428, Feature360
# 	   Feature42, Feature285, Feature141, Feature172, Feature264, Feature608, Feature313, Feature47, Feature488, Feature294
#
# Normalizing layer: counts
#
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  Feature530, Feature565, Feature356, Feature234, Feature456, Feature393, Feature37, Feature194, Feature278, Feature172
# 	   Feature297, Feature248, Feature392, Feature651, Feature418, Feature293, Feature432, Feature589, Feature400, Feature79
# 	   Feature493, Feature208, Feature586, Feature520, Feature337, Feature134, Feature63, Feature90, Feature355, Feature347
# Negative:  Feature305, Feature647, Feature329, Feature286, Feature57, Feature663, Feature145, Feature587, Feature283, Feature473
# 	   Feature252, Feature287, Feature83, Feature43, Feature672, Feature348, Feature631, Feature344, Feature534, Feature671
# 	   Feature512, Feature621, Feature175, Feature308, Feature321, Feature417, Feature161, Feature11, Feature253, Feature174
# PC_ 2
# Positive:  Feature663, Feature305, Feature329, Feature286, Feature57, Feature145, Feature647, Feature587, Feature672, Feature252
# 	   Feature348, Feature278, Feature287, Feature473, Feature83, Feature172, Feature283, Feature43, Feature37, Feature456
# 	   Feature565, Feature631, Feature671, Feature657, Feature175, Feature248, Feature356, Feature530, Feature297, Feature493
# Negative:  Feature691, Feature535, Feature250, Feature11, Feature486, Feature451, Feature429, Feature417, Feature507, Feature160
# 	   Feature529, Feature65, Feature262, Feature489, Feature107, Feature284, Feature518, Feature536, Feature506, Feature5
# 	   Feature478, Feature532, Feature626, Feature294, Feature339, Feature213, Feature379, Feature408, Feature555, Feature20
# PC_ 3
# Positive:  Feature507, Feature429, Feature451, Feature478, Feature11, Feature231, Feature639, Feature532, Feature294, Feature284
# 	   Feature5, Feature339, Feature417, Feature555, Feature149, Feature335, Feature489, Feature171, Feature605, Feature88
# 	   Feature232, Feature143, Feature20, Feature466, Feature317, Feature210, Feature49, Feature48, Feature423, Feature113
# Negative:  Feature691, Feature535, Feature486, Feature298, Feature250, Feature262, Feature529, Feature408, Feature107, Feature266
# 	   Feature213, Feature379, Feature518, Feature626, Feature65, Feature160, Feature178, Feature506, Feature536, Feature105
# 	   Feature343, Feature527, Feature367, Feature680, Feature8, Feature610, Feature599, Feature663, Feature161, Feature267
# PC_ 4
# Positive:  Feature395, Feature157, Feature642, Feature146, Feature542, Feature25, Feature121, Feature656, Feature580, Feature272
# 	   Feature691, Feature554, Feature13, Feature541, Feature585, Feature197, Feature189, Feature137, Feature292, Feature416
# 	   Feature594, Feature151, Feature227, Feature33, Feature175, Feature236, Feature258, Feature334, Feature6, Feature116
# Negative:  Feature620, Feature31, Feature254, Feature644, Feature567, Feature330, Feature545, Feature340, Feature168, Feature386
# 	   Feature165, Feature461, Feature460, Feature500, Feature476, Feature125, Feature637, Feature433, Feature624, Feature310
# 	   Feature479, Feature145, Feature76, Feature214, Feature614, Feature425, Feature451, Feature320, Feature239, Feature376
# PC_ 5
# Positive:  Feature552, Feature361, Feature478, Feature510, Feature242, Feature452, Feature615, Feature31, Feature280, Feature19
# 	   Feature515, Feature491, Feature55, Feature308, Feature390, Feature362, Feature553, Feature403, Feature697, Feature300
# 	   Feature690, Feature376, Feature314, Feature105, Feature650, Feature180, Feature119, Feature215, Feature448, Feature161
# Negative:  Feature628, Feature165, Feature1, Feature593, Feature259, Feature96, Feature394, Feature332, Feature395, Feature637
# 	   Feature548, Feature549, Feature449, Feature196, Feature187, Feature453, Feature219, Feature337, Feature112, Feature147
# 	   Feature318, Feature582, Feature58, Feature34, Feature189, Feature528, Feature698, Feature244, Feature666, Feature692
#
# Warning message:
# “Key ‘PC_’ taken, using ‘spca_’ instead”
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
#
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
#
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Calculating kernel bandwidths
#
# Warning message in FindMultiModalNeighbors(s_obj, reduction.list = list("upca", :
# “The number of provided modality.weight.name is not equal to the number of modalities. URNA.weight SRNA.weight are used to store the modality weights”
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
#   Method     Clustering   Matrices Hyperparam HVGs Data           ARI AMI
# 1 WNN-Leiden 31, 25, .... U,S      0.75       1100 negctrl_sim_k1 0   0
# 2 WNN-Leiden 48, 79, .... U,S      1.00       1100 negctrl_sim_k1 0   0
# 3 WNN-Leiden 81, 161,.... U,S      1.50       1100 negctrl_sim_k1 0   0
# 4 WNN-Leiden 193, 130.... U,S      2.00       1100 negctrl_sim_k1 0   0
# 5 WNN-Leiden 31, 25, .... U,S      0.75       1100 negctrl_sim_k1 0   0
# 6 WNN-Leiden 48, 79, .... U,S      1.00       1100 negctrl_sim_k1 0   0

# %%
xy
# Out:
#    Method     Clustering   Matrices Hyperparam HVGs Data           ARI
# 1  WNN-Leiden 31, 25, .... U,S      0.75       1100 negctrl_sim_k1 0.0000000
# 2  WNN-Leiden 48, 79, .... U,S      1.00       1100 negctrl_sim_k1 0.0000000
# 3  WNN-Leiden 81, 161,.... U,S      1.50       1100 negctrl_sim_k1 0.0000000
# 4  WNN-Leiden 193, 130.... U,S      2.00       1100 negctrl_sim_k1 0.0000000
# 5  WNN-Leiden 31, 25, .... U,S      0.75       1100 negctrl_sim_k1 0.0000000
# 6  WNN-Leiden 48, 79, .... U,S      1.00       1100 negctrl_sim_k1 0.0000000
# 7  WNN-Leiden 81, 161,.... U,S      1.50       1100 negctrl_sim_k1 0.0000000
# 8  WNN-Leiden 193, 130.... U,S      2.00       1100 negctrl_sim_k1 0.0000000
# 9  WNN-Leiden 31, 25, .... U,S      0.75       1100 negctrl_sim_k1 0.0000000
# 10 WNN-Leiden 48, 79, .... U,S      1.00       1100 negctrl_sim_k1 0.0000000
# 11 WNN-Leiden 81, 161,.... U,S      1.50       1100 negctrl_sim_k1 0.0000000
# 12 WNN-Leiden 193, 130.... U,S      2.00       1100 negctrl_sim_k1 0.0000000
# 13 WNN-Leiden 9, 9, 9,.... U,S      0.75       1100 b_beta_sim_k8  1.0000000
# 14 WNN-Leiden 9, 9, 9,.... U,S      1.00       1100 b_beta_sim_k8  1.0000000
# 15 WNN-Leiden 9, 9, 9,.... U,S      1.50       1100 b_beta_sim_k8  1.0000000
# 16 WNN-Leiden 9, 9, 9,.... U,S      2.00       1100 b_beta_sim_k8  1.0000000
# 17 WNN-Leiden 9, 9, 9,.... U,S      0.75       1100 b_beta_sim_k8  1.0000000
# 18 WNN-Leiden 9, 9, 9,.... U,S      1.00       1100 b_beta_sim_k8  1.0000000
# 19 WNN-Leiden 9, 9, 9,.... U,S      1.50       1100 b_beta_sim_k8  1.0000000
# 20 WNN-Leiden 9, 9, 9,.... U,S      2.00       1100 b_beta_sim_k8  1.0000000
# 21 WNN-Leiden 9, 9, 9,.... U,S      0.75       1100 b_beta_sim_k8  1.0000000
# 22 WNN-Leiden 9, 9, 9,.... U,S      1.00       1100 b_beta_sim_k8  1.0000000
# 23 WNN-Leiden 9, 9, 9,.... U,S      1.50       1100 b_beta_sim_k8  1.0000000
# 24 WNN-Leiden 9, 9, 9,.... U,S      2.00       1100 b_beta_sim_k8  1.0000000
# 25 WNN-Leiden 5, 5, 5,.... U,S      0.75        700 k_gamma_sim_k8 0.9987491
# 26 WNN-Leiden 5, 5, 5,.... U,S      1.00        700 k_gamma_sim_k8 0.9987491
# 27 WNN-Leiden 5, 5, 5,.... U,S      1.50        700 k_gamma_sim_k8 0.9633631
# 28 WNN-Leiden 11, 11, .... U,S      2.00        700 k_gamma_sim_k8 0.4427988
# 29 WNN-Leiden 5, 5, 5,.... U,S      0.75        700 k_gamma_sim_k8 0.9987491
# 30 WNN-Leiden 5, 5, 5,.... U,S      1.00        700 k_gamma_sim_k8 0.9987491
# 31 WNN-Leiden 5, 5, 5,.... U,S      1.50        700 k_gamma_sim_k8 0.9633631
# 32 WNN-Leiden 11, 11, .... U,S      2.00        700 k_gamma_sim_k8 0.4427988
# 33 WNN-Leiden 5, 5, 5,.... U,S      0.75        700 k_gamma_sim_k8 0.9987491
# 34 WNN-Leiden 5, 5, 5,.... U,S      1.00        700 k_gamma_sim_k8 0.9987491
# 35 WNN-Leiden 5, 5, 5,.... U,S      1.50        700 k_gamma_sim_k8 0.9633631
# 36 WNN-Leiden 11, 11, .... U,S      2.00        700 k_gamma_sim_k8 0.4427988
#    AMI
# 1  0.0000000
# 2  0.0000000
# 3  0.0000000
# 4  0.0000000
# 5  0.0000000
# 6  0.0000000
# 7  0.0000000
# 8  0.0000000
# 9  0.0000000
# 10 0.0000000
# 11 0.0000000
# 12 0.0000000
# 13 1.0000000
# 14 1.0000000
# 15 1.0000000
# 16 1.0000000
# 17 1.0000000
# 18 1.0000000
# 19 1.0000000
# 20 1.0000000
# 21 1.0000000
# 22 1.0000000
# 23 1.0000000
# 24 1.0000000
# 25 0.9963842
# 26 0.9963842
# 27 0.9191508
# 28 0.5774205
# 29 0.9963842
# 30 0.9963842
# 31 0.9191508
# 32 0.5774205
# 33 0.9963842
# 34 0.9963842
# 35 0.9191508
# 36 0.5774205
